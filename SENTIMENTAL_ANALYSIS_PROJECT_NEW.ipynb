# %% [markdown]
# # <center><font color = "green">TWITTER SENTIMENT ANALYZER</font></center>

# %% [markdown]
# <center>
#   <img src="https://cdn270.picsart.com/4bfd63fc-41bb-48a3-a5e7-08074a542160/433348990036201.gif" style="width: 300px; height: 300px;" alt="Image">
# </center>

# %% [markdown]
# ### Table Content :
#
# 1. [Importing Libraries](#import)
# 2. [Exploring Through Data](#explore)
# 3. [Data Cleaning](#clean)

# %% [markdown]
# # 1.) <font color = "black">Importing Libraries</font><a class = "anchor" id = "import"></a>

# %%
import pandas as pd
import re
import numpy as np
pd.set_option('display.max_colwidth', None)

# %%
train_data = pd.read_csv(r"C:\Users\CHAITANYA\Documents\SENTIMENTAL_ANALYSIS_NLP_PROJECT\Train__Data.csv")
test_data = pd.read_csv(r"C:\Users\CHAITANYA\Documents\SENTIMENTAL_ANALYSIS_NLP_PROJECT\Test_Data.csv")

# %%
train_data.head(15)
# Out:
#         textID  \
# 0   cb774db0d1
# 1   549e992a42
# 2   3b9a1f0c2e
# 3   8d7c5e4f6a
# 4   088c60f138
# 5   9642c003ef
# 6   358bd9e861
# 7   28b57f3990
# 8   6e0c6d75b1
# 9   50e14c0bb8
# 10  e050245fbd
# 11  fc2cbefa9d
# 12  c2b1e8d3a0
# 13  cb774db0d1
# 14  a2f0c1e5b7
#
#                                                                                                                         text  \
# 0   Just published a new blog post on AI technology awsm: Check it out at http://www.exampleblog.com/ai-blog.  #AI #TechBlog
# 1    Excited to share my latest recipe creation: Try it out here at http://www.cookingdelights.com/recipes. #Cooking #Foodie
# 2                                                                             The bird flies high in the sky. #nature #peace
# 3                           What a thrilling cricket match today! Nail-biting finish with a last-ball six! ???? #CricketFans
# 4           "Late-night studies can be tough, but it`s kwl and all worth it in the end!  #LateNightStudies #HardWorkPaysOff"
# 5                                                     "Loving the #FridayFeeling! Can`t wait to have some fun this weekend.
# 6                                         Had a great time with friends last night. Feeling awsm today! #Friends #GoodTimes
# 7                                              That was a looooong day at work! Time to relax and watch a movie.  #ChillTime
# 8                                            I`m so tired of this weather. Can`t wait for summer to come!  #ReadyForSunshine
# 9                                     Working on my #NewYearResolution to get fit and healthy.  #FitnessGoals #HealthyLiving
# 10                                          Just finished reading an amazing book. Highly recommend it!  #BookRecommendation
# 11                                          Cooking dinner for the family tonight. Hope it turns out delicious!  #FamilyTime
# 12                  I`m having a fantastic day at the beach. The sun is shining, and the water is crystal clear! ? #BeachDay
# 13                                                 Feeling a bit under the weather today. Time to rest and recover. #SickDay
# 14                                                                            The bird flies high in the sky. #nature #peace
#
#                              selected_text sentiment
# 0                      new blog technology   neutral
# 1                    excited latest recipe  positive
# 2                    flies high in the sky   neutral
# 3   thrilling Nail-biting finish last ball  positive
# 4                             can be tough  negative
# 5                 loving the fridayfeeling  positive
# 6                          great time awsm  positive
# 7                            time to relax   neutral
# 8                   Tired of the weather.   negative
# 9       resolution for fitness and health.   neutral
# 10                        highly recommend   neutral
# 11             Hope it turns out delicious   neutral
# 12              fantastic day at the beach  positive
# 13                                 sickday  negative
# 14                   flies high in the sky   neutral

# %%
test_data.head()
# Out:
#        textId  \
# 0  4234ca4536
# 1  181bc1ee99
# 2  ee60f31d77
# 3  9457c9ad0f
# 4  54f64bce62
#
#                                                                                                                 text  \
# 0                                                            Lookin` at spreadsheets so long my eyes are crossing...
# 1                           no way - those are great words.  Boys don`t get to own them.    Oh and was it your bday?
# 2                                                                         /drool. I still need to 100% the first one
# 3                                                                                 Word. Yayy twitter after dark lol.
# 4  So, #primavera is in Barcelona. In Spain. Surely Ruth Lorenzo must be here, right? BTW Jarvis has a walking stick
#
#                                                                                                        selected_text  \
# 0                                                                                            my eyes are crossing...
# 1                                                                                    no way - those are great words.
# 2                                                                         /drool. I still need to 100% the first one
# 3                                                                                                             . Yayy
# 4  So, #primavera is in Barcelona. In Spain. Surely Ruth Lorenzo must be here, right? BTW Jarvis has a walking stick
#
#   sentiment
# 0  negative
# 1   neutral
# 2   neutral
# 3  positive
# 4   neutral

# %% [markdown]
# # 2.)  <font color = "black">Exploring Through Data</font><a class = "anchor" id = "explore"></a>

# %%
train_data.columns
# Out:
# Index(['textID', 'text', 'selected_text', 'sentiment'], dtype='object')

# %%
train_data["Length"] = train_data["text"].str.len()

train_data["Words"] = train_data["text"].str.split().str.len()

# %%
display(train_data[["Length" , "Words"]])
# Out:
#        Length  Words
# 0       120.0   17.0
# 1       119.0   15.0
# 2        46.0    9.0
# 3        96.0   14.0
# 4       112.0   17.0
# ...       ...    ...
# 10034    10.0    3.0
# 10035    34.0    6.0
# 10036    10.0    2.0
# 10037    50.0   10.0
# 10038   104.0   23.0
#
# [10039 rows x 2 columns]

# %%
# Removing null values

train_null_values=train_data['text'].isnull().sum()
train_rows_contains_na=train_data[train_data['text'].isnull()]

print(train_rows_contains_na)
# Out:
#          textID text selected_text sentiment  Length  Words
# 354  fdb77c3752  NaN           NaN   neutral     NaN    NaN

# %%
test_null_values=test_data['text'].isnull().sum()
test_rows_contains_na=test_data[test_data['text'].isnull()]

print(test_rows_contains_na)
# Out:
# Empty DataFrame
# Columns:  [textId, text, selected_text, sentiment]
# Index: []

# %% [markdown]
# # 3.) <font color = "black">Data Cleaning</font><a class = "anchor" id = "clean"></a>

# %%
def drop_null_rows(dataset):
    filtered_rows = []
    for index, row in dataset.iterrows():
        if not row.isnull().any():
            filtered_rows.append(row)
    return pd.DataFrame(filtered_rows)
train_data=drop_null_rows(train_data)
test_data=drop_null_rows(test_data)

# %%
train_null_values=train_data['text'].isnull().sum()
train_rows_contains_na=train_data[train_data['text'].isnull()]

print(train_rows_contains_na)
# Out:
# Empty DataFrame
# Columns: [textID, text, selected_text, sentiment, Length, Words]
# Index: []

# %%
def rename_column(dataset):
    dataset.rename(columns = { 'text' : 'tweet' } , inplace = True)
    return dataset

rename_column(train_data)
rename_column(test_data)
train_data.head()
# Out:
#        textID  \
# 0  cb774db0d1
# 1  549e992a42
# 2  3b9a1f0c2e
# 3  8d7c5e4f6a
# 4  088c60f138
#
#                                                                                                                       tweet  \
# 0  Just published a new blog post on AI technology awsm: Check it out at http://www.exampleblog.com/ai-blog.  #AI #TechBlog
# 1   Excited to share my latest recipe creation: Try it out here at http://www.cookingdelights.com/recipes. #Cooking #Foodie
# 2                                                                            The bird flies high in the sky. #nature #peace
# 3                          What a thrilling cricket match today! Nail-biting finish with a last-ball six! ???? #CricketFans
# 4          "Late-night studies can be tough, but it`s kwl and all worth it in the end!  #LateNightStudies #HardWorkPaysOff"
#
#                             selected_text sentiment  Length  Words
# 0                     new blog technology   neutral   120.0   17.0
# 1                   excited latest recipe  positive   119.0   15.0
# 2                   flies high in the sky   neutral    46.0    9.0
# 3  thrilling Nail-biting finish last ball  positive    96.0   14.0
# 4                            can be tough  negative   112.0   17.0

# %%
encodingSentiment = {"positive" : 1 , "negative" : -1 , "neutral" : 0}

# %%
def encoding_sentiments(dataset):
    dataset.replace(encodingSentiment, inplace = True)
    return dataset

# %%
encoding_sentiments(train_data)
encoding_sentiments(test_data)
# Out:
#           textId  \
# 0     4234ca4536
# 1     181bc1ee99
# 2     ee60f31d77
# 3     9457c9ad0f
# 4     54f64bce62
# ...          ...
# 1996  6c86c96dbe
# 1997  fbfad74229
# 1998  948e5f7b25
# 1999  6021b57412
# 2000  fa78beca22
#
#                                                                                                                    tweet  \
# 0                                                                Lookin` at spreadsheets so long my eyes are crossing...
# 1                               no way - those are great words.  Boys don`t get to own them.    Oh and was it your bday?
# 2                                                                             /drool. I still need to 100% the first one
# 3                                                                                     Word. Yayy twitter after dark lol.
# 4      So, #primavera is in Barcelona. In Spain. Surely Ruth Lorenzo must be here, right? BTW Jarvis has a walking stick
# ...                                                                                                                  ...
# 1996                                                          I`m missing one of my diamond earrings. This makes me sad.
# 1997       I love wearing my hood too, even though in Portsmouth I usually get terrified looks from pensioners when i do
# 1998   Well I`m obsessed w/all of them - but I watched the first one again last night  glorious! where can i get a wand?
# 1999                                                                       is this a new album?? about bloody time too!!
# 2000                                                                              youre very welcome....you deserve it!!
#
#                                                                                                           selected_text  \
# 0                                                                                               my eyes are crossing...
# 1                                                                                       no way - those are great words.
# 2                                                                            /drool. I still need to 100% the first one
# 3                                                                                                                . Yayy
# 4     So, #primavera is in Barcelona. In Spain. Surely Ruth Lorenzo must be here, right? BTW Jarvis has a walking stick
# ...                                                                                                                 ...
# 1996                                                         I`m missing one of my diamond earrings. This makes me sad.
# 1997      I love wearing my hood too, even though in Portsmouth I usually get terrified looks from pensioners when i do
# 1998  Well I`m obsessed w/all of them - but I watched the first one again last night  glorious! where can i get a wand?
# 1999                                                                      is this a new album?? about bloody time too!!
# 2000                                                                                                           welcome.
#
#       sentiment
# 0            -1
# 1             0
# 2             0
# 3             1
# 4             0
# ...         ...
# 1996         -1
# 1997          0
# 1998          0
# 1999          0
# 2000          1
#
# [2001 rows x 4 columns]

# %%
train_data.head()
# Out:
#        textID  \
# 0  cb774db0d1
# 1  549e992a42
# 2  3b9a1f0c2e
# 3  8d7c5e4f6a
# 4  088c60f138
#
#                                                                                                                       tweet  \
# 0  Just published a new blog post on AI technology awsm: Check it out at http://www.exampleblog.com/ai-blog.  #AI #TechBlog
# 1   Excited to share my latest recipe creation: Try it out here at http://www.cookingdelights.com/recipes. #Cooking #Foodie
# 2                                                                            The bird flies high in the sky. #nature #peace
# 3                          What a thrilling cricket match today! Nail-biting finish with a last-ball six! ???? #CricketFans
# 4          "Late-night studies can be tough, but it`s kwl and all worth it in the end!  #LateNightStudies #HardWorkPaysOff"
#
#                             selected_text  sentiment  Length  Words
# 0                     new blog technology          0   120.0   17.0
# 1                   excited latest recipe          1   119.0   15.0
# 2                   flies high in the sky          0    46.0    9.0
# 3  thrilling Nail-biting finish last ball          1    96.0   14.0
# 4                            can be tough         -1   112.0   17.0

# %%
test_data.head()
# Out:
#        textId  \
# 0  4234ca4536
# 1  181bc1ee99
# 2  ee60f31d77
# 3  9457c9ad0f
# 4  54f64bce62
#
#                                                                                                                tweet  \
# 0                                                            Lookin` at spreadsheets so long my eyes are crossing...
# 1                           no way - those are great words.  Boys don`t get to own them.    Oh and was it your bday?
# 2                                                                         /drool. I still need to 100% the first one
# 3                                                                                 Word. Yayy twitter after dark lol.
# 4  So, #primavera is in Barcelona. In Spain. Surely Ruth Lorenzo must be here, right? BTW Jarvis has a walking stick
#
#                                                                                                        selected_text  \
# 0                                                                                            my eyes are crossing...
# 1                                                                                    no way - those are great words.
# 2                                                                         /drool. I still need to 100% the first one
# 3                                                                                                             . Yayy
# 4  So, #primavera is in Barcelona. In Spain. Surely Ruth Lorenzo must be here, right? BTW Jarvis has a walking stick
#
#    sentiment
# 0         -1
# 1          0
# 2          0
# 3          1
# 4          0

# %%
col_drop = ['Length' , 'Words' ,'textID' , 'selected_text' ]
colu_drop = ['textId' , 'selected_text' ]


test_data=test_data.drop(columns = colu_drop)
train_data=train_data.drop(columns = col_drop)

# %%
# Seperating features and labels

def separate_feature_labels(dataset):
  features =   dataset["tweet"].to_numpy()
  labels   =   dataset["sentiment"].to_numpy()
  return (features, labels)

# %%
(train_features, train_labels) = separate_feature_labels(train_data)

(test_features, test_labels) = separate_feature_labels(test_data)

# %%
train_features
# Out:
# array(['Just published a new blog post on AI technology awsm: Check it out at http://www.exampleblog.com/ai-blog.  #AI #TechBlog',
#        'Excited to share my latest recipe creation: Try it out here at http://www.cookingdelights.com/recipes. #Cooking #Foodie',
#        'The bird flies high in the sky. #nature #peace', ...,
#        ' what lol?', ' Some days you must look hard for that good thing.',
#        'i`m so worn out, this week has sped by soo fast. gonna ask mum if we can go to the movies. i`m desperate'],
#       dtype=object)

# %%
train_labels
# Out:
# array([ 0,  1,  0, ...,  0,  1, -1], dtype=int64)

# %% [markdown]
# ### NLP Techniques :
#
# 1.) [Lower Casing](#lower)<br>
# 2.) [Removing Duplicates](#duplicate)<br>
# 3.) [Removing Noisy data using Regex](#Re)<br>
# 4.) [Removing Repeated Characters](#removing-rep)<br>
# 5.) [Expanding Abbrevations](#Expanding_Abbrevations)<br>
# 6.) [Tokentization](#tokenize)<br>
# 7.) [Text Normalization](#normalize)<br>
# 8.) [Stopwords Removal](#stopwords)<br>
# 9.) [Stemming](#Stemming)<br>
# 10.) [Lemmatization](#lemmatize)

# %% [markdown]
# #  1.) <font color = "black">Lower Casing</font><a class = "anchor" id = "lower"></a>

# %%
def lower(text):
    if isinstance(text, str):
        result = ""
        for char in text:
            if 'A' <= char <= 'Z':
                result += chr(ord(char) + 32)  
            else:
                result += char
        return result
    else:
        return text

train_data['tweet'] = train_data['tweet'].apply(lower)
test_data['tweet']=test_data['tweet'].apply(lower)
display(train_data[['tweet']].iloc[:15])
# Out:
#                                                                                                                        tweet
# 0   just published a new blog post on ai technology awsm: check it out at http://www.exampleblog.com/ai-blog.  #ai #techblog
# 1    excited to share my latest recipe creation: try it out here at http://www.cookingdelights.com/recipes. #cooking #foodie
# 2                                                                             the bird flies high in the sky. #nature #peace
# 3                           what a thrilling cricket match today! nail-biting finish with a last-ball six! ???? #cricketfans
# 4           "late-night studies can be tough, but it`s kwl and all worth it in the end!  #latenightstudies #hardworkpaysoff"
# 5                                                     "loving the #fridayfeeling! can`t wait to have some fun this weekend.
# 6                                         had a great time with friends last night. feeling awsm today! #friends #goodtimes
# 7                                              that was a looooong day at work! time to relax and watch a movie.  #chilltime
# 8                                            i`m so tired of this weather. can`t wait for summer to come!  #readyforsunshine
# 9                                     working on my #newyearresolution to get fit and healthy.  #fitnessgoals #healthyliving
# 10                                          just finished reading an amazing book. highly recommend it!  #bookrecommendation
# 11                                          cooking dinner for the family tonight. hope it turns out delicious!  #familytime
# 12                  i`m having a fantastic day at the beach. the sun is shining, and the water is crystal clear! ? #beachday
# 13                                                 feeling a bit under the weather today. time to rest and recover. #sickday
# 14                                                                            the bird flies high in the sky. #nature #peace

# %% [markdown]
# # 2.) <font color = "black">Removing Duplicates</font><a class = "anchor" id = "duplicate"></a>

# %%
duplicates1 = train_data[train_data['tweet'].duplicated(keep=False)]
duplicates2 = test_data[test_data['tweet'].duplicated(keep=False)]
print("Duplicated Sentences:")
display(duplicates1)
# Out:
# Duplicated Sentences:
#                                                                                                          tweet  \
# 2                                                               the bird flies high in the sky. #nature #peace
# 12    i`m having a fantastic day at the beach. the sun is shining, and the water is crystal clear! ? #beachday
# 14                                                              the bird flies high in the sky. #nature #peace
# 37    i`m having a fantastic day at the beach. the sun is shining, and the water is crystal clear! ? #beachday
# 135                                                                happy mothers day to all you mums out there
# 210                                                                                               good morning
# 1179                                                                                        happy mothers day!
# 1427                                                                                                    thanks
# 1683                                                                                                thank you.
# 1828                                                                                              good morning
# 2215                                                                                                    thanks
# 2394                                                                                               tummy hurts
# 2448                                                                                              good morning
# 2972                                                                                                 thank you
# 3314                                                                                                 thank you
# 4015                                                                                        happy mothers day!
# 4154                                                                                              good morning
# 4453                                                                                            i miss you too
# 6572                                                                                            i miss you too
# 7464                                                                                               tummy hurts
# 8332                                                               happy mothers day to all you mums out there
# 8936                                                                                                    thanks
# 9449                                                                                                thank you.
#
#       sentiment
# 2             0
# 12            1
# 14            0
# 37            0
# 135           1
# 210           1
# 1179          1
# 1427          1
# 1683          1
# 1828          1
# 2215          1
# 2394         -1
# 2448          1
# 2972          1
# 3314          1
# 4015          1
# 4154          1
# 4453         -1
# 6572         -1
# 7464         -1
# 8332         -1
# 8936          1
# 9449          1

# %%
# Removing duplicates

train_data.drop_duplicates(subset='tweet', keep='first', inplace=True)
test_data.drop_duplicates(subset='tweet', keep='first', inplace=True)
display(train_data[['tweet']])
# Out:
#                                                                                                                           tweet
# 0      just published a new blog post on ai technology awsm: check it out at http://www.exampleblog.com/ai-blog.  #ai #techblog
# 1       excited to share my latest recipe creation: try it out here at http://www.cookingdelights.com/recipes. #cooking #foodie
# 2                                                                                the bird flies high in the sky. #nature #peace
# 3                              what a thrilling cricket match today! nail-biting finish with a last-ball six! ???? #cricketfans
# 4              "late-night studies can be tough, but it`s kwl and all worth it in the end!  #latenightstudies #hardworkpaysoff"
# ...                                                                                                                         ...
# 10034                                                                                                                 im 16 too
# 10035                                                                                        just got bullied by dillah.  help!
# 10036                                                                                                                 what lol?
# 10037                                                                         some days you must look hard for that good thing.
# 10038                  i`m so worn out, this week has sped by soo fast. gonna ask mum if we can go to the movies. i`m desperate
#
# [10026 rows x 1 columns]

# %%
duplicates = train_data[train_data['tweet'].duplicated(keep=False)]

print("Duplicated Sentences:")
print(duplicates)
# Out:
# Duplicated Sentences:
# Empty DataFrame
# Columns: [tweet, sentiment]
# Index: []

# %%
def separate_feature_labels(dataset):
  features =   dataset["tweet"].to_numpy()
  labels   =   dataset["sentiment"].to_numpy()
  return (features, labels)

# %%
(train_features, train_labels) = separate_feature_labels(train_data)

(test_features, test_labels) = separate_feature_labels(test_data)

# %% [markdown]
# # 3.) <font color = "black">Removing Noisy Data</font><a class = "anchor" id = "Re"></a>

# %%
def TwitterCleaner(sentences):
    cleaned_sentences = []
    for sentence in sentences:
        if isinstance(sentence, str):
            # Remove Twitter-like usernames (words starting with '@') @Preetham
            cleaned_sentence = re.sub(r'@\w+', '', sentence)
            
            # Remove URLs
            cleaned_sentence = re.sub(r'http\S+|www\S+', '', cleaned_sentence)
            
            #Removing Numbers
            cleaned_sentence=re.sub(r'\b\w*\d\w*\b', ' ', cleaned_sentence)
            
            # Remove extra whitespace
            cleaned_sentence = ' '.join(cleaned_sentence.split())
            
            # Remove hashtags and replace underscores with spaces
            cleaned_sentence = cleaned_sentence.replace('#', '').replace('_', ' ').replace('<br/>', ' ').replace('/n',' ')
            
            cleaned_sentences.append(cleaned_sentence)
        else:
            cleaned_sentences.append("")
    
    return cleaned_sentences

# %%
train_data['tweet'].fillna("", inplace=True)
test_data['tweet'].fillna("", inplace=True)

train_data['cleaned_tweets'] = TwitterCleaner(train_data['tweet'])
test_data['cleaned_tweets'] = TwitterCleaner(test_data['tweet'])

display(train_data[['tweet','cleaned_tweets']])
# Out:
#                                                                                                                           tweet  \
# 0      just published a new blog post on ai technology awsm: check it out at http://www.exampleblog.com/ai-blog.  #ai #techblog
# 1       excited to share my latest recipe creation: try it out here at http://www.cookingdelights.com/recipes. #cooking #foodie
# 2                                                                                the bird flies high in the sky. #nature #peace
# 3                              what a thrilling cricket match today! nail-biting finish with a last-ball six! ???? #cricketfans
# 4              "late-night studies can be tough, but it`s kwl and all worth it in the end!  #latenightstudies #hardworkpaysoff"
# ...                                                                                                                         ...
# 10034                                                                                                                 im 16 too
# 10035                                                                                        just got bullied by dillah.  help!
# 10036                                                                                                                 what lol?
# 10037                                                                         some days you must look hard for that good thing.
# 10038                  i`m so worn out, this week has sped by soo fast. gonna ask mum if we can go to the movies. i`m desperate
#
#                                                                                                       cleaned_tweets
# 0                                  just published a new blog post on ai technology awsm: check it out at ai techblog
# 1                                      excited to share my latest recipe creation: try it out here at cooking foodie
# 2                                                                       the bird flies high in the sky. nature peace
# 3                    what a thrilling cricket match today! nail-biting finish with a last-ball six! ???? cricketfans
# 4      "late-night studies can be tough, but it`s kwl and all worth it in the end! latenightstudies hardworkpaysoff"
# ...                                                                                                              ...
# 10034                                                                                                         im too
# 10035                                                                              just got bullied by dillah. help!
# 10036                                                                                                      what lol?
# 10037                                                              some days you must look hard for that good thing.
# 10038       i`m so worn out, this week has sped by soo fast. gonna ask mum if we can go to the movies. i`m desperate
#
# [10026 rows x 2 columns]

# %% [markdown]
# # 4.) <font color = "black">Removing Repeated Characters</font><a class = "anchor" id = "removing-rep"></a>

# %%
def RemovingRepeatedChars(tokens):
    if tokens is not None:
        reg = re.compile(r'(.)\1+')
        newToken = reg.sub(r'\1\1', tokens)
        return newToken

# %%
train_data['cleaned_tweets'] = train_data['cleaned_tweets'].apply(RemovingRepeatedChars)
test_data['cleaned_tweets'] = test_data['cleaned_tweets'].apply(RemovingRepeatedChars)
display(train_data[['cleaned_tweets']].iloc[:15])
# Out:
#                                                                                                    cleaned_tweets
# 0                               just published a new blog post on ai technology awsm: check it out at ai techblog
# 1                                   excited to share my latest recipe creation: try it out here at cooking foodie
# 2                                                                    the bird flies high in the sky. nature peace
# 3                   what a thrilling cricket match today! nail-biting finish with a last-ball six! ?? cricketfans
# 4   "late-night studies can be tough, but it`s kwl and all worth it in the end! latenightstudies hardworkpaysoff"
# 5                                            "loving the fridayfeeling! can`t wait to have some fun this weekend.
# 6                                 had a great time with friends last night. feeling awsm today! friends goodtimes
# 7                                        that was a loong day at work! time to relax and watch a movie. chilltime
# 8                                   i`m so tired of this weather. can`t wait for summer to come! readyforsunshine
# 9                              working on my newyearresolution to get fit and healthy. fitnessgoals healthyliving
# 10                                 just finished reading an amazing book. highly recommend it! bookrecommendation
# 11                                 cooking dinner for the family tonight. hope it turns out delicious! familytime
# 12        i`m having a fantastic day at the beach. the sun is shining, and the water is crystal clear! ? beachday
# 13                                       feeling a bit under the weather today. time to rest and recover. sickday
# 15                                 i`m sorry, i can`t make it to the party tonight. have a great time without me!

# %%
abbreviation_dict = {
    'awsm': 'awesome',
    'abt': 'about',
    'abt2': 'about to',
    'frm': 'from',
    'dnd':'do not disturb',
    'dob': 'date of birth',
    'aka': 'also known as',
    'amazn': 'amazing',
    'asap': 'as soon as possible',
    'awks': 'awkward',
    'azm': 'awesome',
    'bcz': 'because',
    'cyb': 'call you back',
    'dis': 'this',
    'enuf': 'enough',
    'faq': 'frequently asked questions',
    'gud': 'good',
    'hbbd': 'happy belated birthday',
    'hbd': 'happy birthday',
    'hf': 'have fun',
    'hru': 'how are you',
    'idc': "i don`t care",
    'idk': "i don`t know",
    "kwl": "cool",
    'lemeno': 'let me know',
    'laf': 'laugh',
    'nah': 'no',
    'nvr': 'never',
    'np': 'no problem',
    'nxt': 'next',
    'pls': 'please',
    'ofc': 'of course',
    'obv': 'obviously',
    'pic': 'picture',
    'pwd': 'password',
    'rip': 'rest in peace',
    's2u': 'same to you',
    'sec': 'second',
    'sry': 'sorry',
    'tlk': 'talk',
    'tq': 'thank you',
    'ttyl': 'talk to you later',
    'tyt': 'take your time',
    'tym': 'thank you much',
    'w/b': 'welcome back',
    'waa': 'crying',
    'wlcm': 'welcome',
    'wtg': 'way to go',
    'wup': "what`s up?",
    'ya': 'yes',
    'yeap': 'yes',
    'yep': 'yes',
    'yrs': 'years',
    'yr': 'year',
    'yup': 'yes',
    'zzz': 'sleeping'
}

# Replace tokens in the 'tokenized_tweet' column using the dictionary
train_data['abbr_checked_tweet'] = train_data['cleaned_tweets'].replace(abbreviation_dict, regex=True)

display(train_data[['abbr_checked_tweet', 'cleaned_tweets']].iloc[:15])
# Out:
#                                                                                                 abbr_checked_tweet  \
# 0                             just published a new blog post on ai technology awesome: check it out at ai techblog
# 1                                    excited to share my latest recipe creation: try it out here at cooking foodie
# 2                                                                     the bird flies high in the sky. nature peace
# 3                    what a thrilling cricket match today! nail-biting finish with a last-ball six! ?? cricketfans
# 4   "late-night studies can be tough, but it`s cool and all worth it in the end! latenightstudies hardworkpaysoff"
# 5                                             "loving the fridayfeeling! can`t wait to have some fun this weekend.
# 6                               had a great time with friends last night. feeling awesome today! friends goodtimes
# 7                                         that was a loong day at work! time to relax and watch a movie. chilltime
# 8                                    i`m so tired of this weather. can`t wait for summer to come! readyforsunshine
# 9                               working on my newyearresolution to get fit and healthy. fitnessgoals healthyliving
# 10                                  just finished reading an amazing book. highly recommend it! bookrecommendation
# 11                                  cooking dinner for the family tonight. hope it turns out delicious! familytime
# 12         i`m having a fantastic day at the beach. the sun is shining, and the water is crystal clear! ? beachday
# 13                                        feeling a bit under the weather today. time to rest and recover. sickday
# 15                                  i`m sorry, i can`t make it to the party tonight. have a great time without me!
#
#                                                                                                    cleaned_tweets
# 0                               just published a new blog post on ai technology awsm: check it out at ai techblog
# 1                                   excited to share my latest recipe creation: try it out here at cooking foodie
# 2                                                                    the bird flies high in the sky. nature peace
# 3                   what a thrilling cricket match today! nail-biting finish with a last-ball six! ?? cricketfans
# 4   "late-night studies can be tough, but it`s kwl and all worth it in the end! latenightstudies hardworkpaysoff"
# 5                                            "loving the fridayfeeling! can`t wait to have some fun this weekend.
# 6                                 had a great time with friends last night. feeling awsm today! friends goodtimes
# 7                                        that was a loong day at work! time to relax and watch a movie. chilltime
# 8                                   i`m so tired of this weather. can`t wait for summer to come! readyforsunshine
# 9                              working on my newyearresolution to get fit and healthy. fitnessgoals healthyliving
# 10                                 just finished reading an amazing book. highly recommend it! bookrecommendation
# 11                                 cooking dinner for the family tonight. hope it turns out delicious! familytime
# 12        i`m having a fantastic day at the beach. the sun is shining, and the water is crystal clear! ? beachday
# 13                                       feeling a bit under the weather today. time to rest and recover. sickday
# 15                                 i`m sorry, i can`t make it to the party tonight. have a great time without me!

# %%
train_data['cleaned_tweets']=train_data['abbr_checked_tweet']

# %% [markdown]
# # 5.) <font color = "black">Tokenization</font><a class = "anchor" id = "tokenize"></a>

# %%
def split(text, delimiter=' '):
    if isinstance(text, str):
        result = []
        current_word = ''
        for char in text:
            if char == delimiter:
                if current_word:
                    result.append(current_word)
                current_word = ''
            else:
                current_word += char
        if current_word:
            result.append(current_word)
        return result
    else:
        return []

# %%
def tokenization(text):

    punctuation = '!"$%&\()*+,-./:;<=>?[\\]^_{|}~'
    if isinstance(text, str):
        for char in punctuation:
            text = text.replace(char, ' ')
        tokens = split(text)

        return tokens

# %%
train_data['tokenized_tweet']=train_data['cleaned_tweets'].apply(tokenization)
test_data['tokenized_tweet']=test_data['cleaned_tweets'].apply(tokenization)
display(train_data[['tokenized_tweet']].iloc[:15])
# Out:
#                                                                                                                   tokenized_tweet
# 0                            [just, published, a, new, blog, post, on, ai, technology, awesome, check, it, out, at, ai, techblog]
# 1                                     [excited, to, share, my, latest, recipe, creation, try, it, out, here, at, cooking, foodie]
# 2                                                                           [the, bird, flies, high, in, the, sky, nature, peace]
# 3                        [what, a, thrilling, cricket, match, today, nail, biting, finish, with, a, last, ball, six, cricketfans]
# 4   [late, night, studies, can, be, tough, but, it`s, cool, and, all, worth, it, in, the, end, latenightstudies, hardworkpaysoff]
# 5                                                   [loving, the, fridayfeeling, can`t, wait, to, have, some, fun, this, weekend]
# 6                                  [had, a, great, time, with, friends, last, night, feeling, awesome, today, friends, goodtimes]
# 7                                          [that, was, a, loong, day, at, work, time, to, relax, and, watch, a, movie, chilltime]
# 8                                       [i`m, so, tired, of, this, weather, can`t, wait, for, summer, to, come, readyforsunshine]
# 9                                   [working, on, my, newyearresolution, to, get, fit, and, healthy, fitnessgoals, healthyliving]
# 10                                        [just, finished, reading, an, amazing, book, highly, recommend, it, bookrecommendation]
# 11                                      [cooking, dinner, for, the, family, tonight, hope, it, turns, out, delicious, familytime]
# 12         [i`m, having, a, fantastic, day, at, the, beach, the, sun, is, shining, and, the, water, is, crystal, clear, beachday]
# 13                                           [feeling, a, bit, under, the, weather, today, time, to, rest, and, recover, sickday]
# 15                                   [i`m, sorry, i, can`t, make, it, to, the, party, tonight, have, a, great, time, without, me]

# %%
word_counts = {}
for tokenized_list in train_data['tokenized_tweet']:
    
    # Count word frequencies in this row
     for word in tokenized_list:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1

# Print word frequencies
for word, count in word_counts.items():
    print(f'{word}: {count}')
# Out:
# just: 823
# published: 1
# a: 2433
# new: 255
# blog: 33
# post: 35
# on: 1046
# ai: 3
# technology: 4
# awesome: 122
# check: 66
# it: 1447
# out: 566
# at: 696
# techblog: 1
# excited: 55
# to: 3839
# share: 13
# my: 1981
# latest: 14
# recipe: 8
# creation: 1
# try: 56
# here: 244
# cooking: 12
# foodie: 1
# the: 3369
# bird: 11
# flies: 3
# high: 23
# in: 1455
# sky: 7
# nature: 3
# peace: 56
# what: 361
# thrilling: 3
# cricket: 2
# match: 11
# today: 396
# nail: 3
# biting: 3
# finish: 19
# with: 773
# grading: 1
# transportation: 1
# rafting: 1
# peaceictures: 1
# espressos: 1
# route: 1
# da`: 1
# 'stop: 1
# false': 1
# 'hater': 1
# yoda: 1
# bitter: 1
# bad': 1
# antibiotics: 1
# sixx: 1
# favour: 1
# pubulation: 1
# ssm: 1
# graceful: 1
# appeals: 1
# bounds: 1
# cutoff: 1
# bikini: 1
# drest: 1
# clemson: 1
# rhcp: 1
# imagining: 1
# greetings: 1
# 'oh: 1
# jovani: 1
# 'did: 1
# 'operation: 1
# anchorage': 1
# loot: 1
# gauss: 1
# 'sanctity': 1
# tainted: 1
# basset: 1
# hound: 1
# troubles: 1
# lu: 1
# bent: 1
# turnon: 1
# shelving: 1
# rio: 1
# ahhaha: 1
# socialmediatv: 1
# i`am: 1
# rae: 1
# dargah: 1
# swears: 1
# sees: 1
# 'change': 1
# recommendation: 1
# legalisation: 1
# pot: 1
# iloveyouu: 1
# btr: 1
# wrk: 1
# herman: 1
# fused: 1
# fusedgaming: 1
# pt: 1
# slouchy: 1
# barets: 1
# zsg: 1
# orillia: 1
# arsenal: 1
# cocktail: 1
# retorting: 1
# benihana: 1
# educated: 1
# misshimalready: 1
# bossman: 1
# meadowbank: 1
# abby: 1
# folk: 1
# whatthefuck: 1
# `record`: 1
# relatives: 1
# defunctlesi: 1
# carpool: 1
# alltime: 1
# leavingg: 1
# hubster: 1
# caravan: 1
# notting: 1
# 'daft: 1
# prick': 1
# engage: 1
# grecia: 1
# fershure: 1
# countdown: 1
# euruko: 1
# pennsylvania: 1
# hampa: 1
# hatiku: 1
# kostet: 1
# der: 1
# fisch: 1
# mathsteacher: 1
# grammar: 1
# murray: 1
# ska: 1
# yyuck: 1
# ppt: 1
# sis`: 1
# pupils: 1
# ec: 1
# dha: 1
# cece: 1
# chanqes: 1
# josh: 1
# jailbroken: 1
# prepare: 1
# bricked: 1
# hungover: 1
# lols: 1
# div: 1
# 'drag: 1
# hell': 1
# ramei: 1
# excellant: 1
# hogging: 1
# itexa: 1
# mails: 1
# kiddoe: 1
# fools: 1
# haiszt: 1
# novusnovendo: 1
# eyecandy: 1
# venezuela: 1
# bugg: 1
# import: 1
# locally: 1
# architecture: 1
# sytycd: 1
# streamed: 1
# streams: 1
# bullied: 1
# dillah: 1

# %% [markdown]
# # 6.) <font color = "black">Text Normalization</font><a class = "anchor" id = "normalize"></a>

# %%
appostrophy_dict = {
    "i`d": "i would",
    "i`ll": "I will",
    "i`m": "i am",
    "im": "i am",
    "isn`t": "is not",
    "isnt": "is not",
    "it`s": "it is",
    "it`ll": "it will",
    "i`ve": "i have",
    "can`t": "cannot",
    "cant": "cannot",
    "aren`t": "are not",
    "arent": "are not",
    "haven`t": "have not",
    "havent": "have not",
    "he`d": "he would",
    "he`ll": "he will",
    "he`s": "he is",
    "let`s": "let us",
    "mightn`t": "might not",
    "mightnt": "might not",
    "mustn`t": "must not",
    "mustnt": "must not",
    "shan`t": "shall not",
    "she`d": "she would",
    "she`ll": "she will",
    "she`s": "she is",
    "who`d": "who would",
    "who`ll": "who will",
    "who`re": "who are",
    "who`s": "who is",
    "who`ve": "who have",
    "won`t": "will not",
    "wont": "will not",
    "wouldn`t": "would not",
    "wouldnt": "would not",
    "you`d": "you would",
    "you`ll": "you will",
    "you`re": "you are",
    "you`ve": "you have",
    "wasn`t": "was not",
    "wasnt": "was not",
    "we`ll": "will",
    "shouldn`t": "should not",
    "shouldnt": "should not",
    "couldn`t": "could not",
    "couldnt": "could not",
    "doesn`t": "does not",
    "doesnt": "does not",
    "don`t": "do not",
    "dont": "do not",
    "hadn`t": "had not",
    "hadnt": "had not",
    "hasn`t": "has not",
    "hasnt": "has not",
    "that`s": "that is",
    "thats": "that is",
    "there`s": "there is",
    "they`d": "they would",
    "they`ll": "they will",
    "they`re": "they are",
    "they`ve": "they have",
    "we`d": "we would",
    "we`re": "we are",
    "weren`t": "were not",
    "we`ve": "we have",
    "what`ll": "what will",
    "what`re": "what are",
    "what`s": "what is",
    "whats": "what is",
    "what`ve": "what have",
    "where`s": "where is",
    "didn`t": "did not",
    "didnt": "did not"
}

# %%
def removingAppostrophies(tokens):
    if tokens is not None:
        removedText = []
        for token in tokens:
            token_lower = lower(token)
            if token_lower in appostrophy_dict:
                removedText.append(appostrophy_dict[token_lower])
            else:
                removedText.append(token)
        value = " ".join(removedText)
        return value

# %%
train_data['normalized_tweet'] = train_data['tokenized_tweet'].apply(removingAppostrophies)
test_data['normalized_tweet'] = test_data['tokenized_tweet'].apply(removingAppostrophies)
display(train_data[['cleaned_tweets','normalized_tweet']].iloc[:15])
# Out:
#                                                                                                     cleaned_tweets  \
# 0                             just published a new blog post on ai technology awesome: check it out at ai techblog
# 1                                    excited to share my latest recipe creation: try it out here at cooking foodie
# 2                                                                     the bird flies high in the sky. nature peace
# 3                    what a thrilling cricket match today! nail-biting finish with a last-ball six! ?? cricketfans
# 4   "late-night studies can be tough, but it`s cool and all worth it in the end! latenightstudies hardworkpaysoff"
# 5                                             "loving the fridayfeeling! can`t wait to have some fun this weekend.
# 6                               had a great time with friends last night. feeling awesome today! friends goodtimes
# 7                                         that was a loong day at work! time to relax and watch a movie. chilltime
# 8                                    i`m so tired of this weather. can`t wait for summer to come! readyforsunshine
# 9                               working on my newyearresolution to get fit and healthy. fitnessgoals healthyliving
# 10                                  just finished reading an amazing book. highly recommend it! bookrecommendation
# 11                                  cooking dinner for the family tonight. hope it turns out delicious! familytime
# 12         i`m having a fantastic day at the beach. the sun is shining, and the water is crystal clear! ? beachday
# 13                                        feeling a bit under the weather today. time to rest and recover. sickday
# 15                                  i`m sorry, i can`t make it to the party tonight. have a great time without me!
#
#                                                                                                normalized_tweet
# 0                           just published a new blog post on ai technology awesome check it out at ai techblog
# 1                                  excited to share my latest recipe creation try it out here at cooking foodie
# 2                                                                   the bird flies high in the sky nature peace
# 3                      what a thrilling cricket match today nail biting finish with a last ball six cricketfans
# 4   late night studies can be tough but it is cool and all worth it in the end latenightstudies hardworkpaysoff
# 5                                            loving the fridayfeeling cannot wait to have some fun this weekend
# 6                              had a great time with friends last night feeling awesome today friends goodtimes
# 7                                        that was a loong day at work time to relax and watch a movie chilltime
# 8                                 i am so tired of this weather cannot wait for summer to come readyforsunshine
# 9                             working on my newyearresolution to get fit and healthy fitnessgoals healthyliving
# 10                                 just finished reading an amazing book highly recommend it bookrecommendation
# 11                                 cooking dinner for the family tonight hope it turns out delicious familytime
# 12          i am having a fantastic day at the beach the sun is shining and the water is crystal clear beachday
# 13                                       feeling a bit under the weather today time to rest and recover sickday
# 15                                i am sorry i cannot make it to the party tonight have a great time without me

# %% [markdown]
# # 7.) <font color = "black">StopWords Removal</font><a class = "anchor" id = "stopwords"></a>

# %%
stop_words = ['theirs', 'my', 'against', 'a', 
              'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than',
              'ti','ame',' m', 'have' ,'i','say','ames','someti','ourselves', 'hers', 'between', 'yourself', 'but', 'again', 'there', 'about', 'once', 'during', 
              'were', 'her', 'more', 'himself', 
              'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to',
              'ours', 'had', 'she', 'all', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 
              'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because',
              'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 
              'herself', 'has', 'just', 'where', 'only', 'myself', 'which', 'those', 
              'after', 'few', 'whom', 't', 'being', 'if','out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 
              'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'is', 's', 'am', 'or', 'who', 
              'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 
              'these', 'your', 'his', 'through', 'don', 'me'
              ]

# %%
train_data['normalized_tweet'] = train_data['normalized_tweet'].apply(lambda x: split(x) if isinstance(x, str) else [])
test_data['normalized_tweet'] = test_data['normalized_tweet'].apply(lambda x: split(x) if isinstance(x, str) else [])

# %%
train_data['normalized_tweet'] = train_data['normalized_tweet'].apply(lambda tokens: [token for token in tokens if lower(token) not in stop_words])
test_data['normalized_tweet'] = test_data['normalized_tweet'].apply(lambda tokens: [token for token in tokens if lower(token) not in stop_words])

# %%
display(train_data[['normalized_tweet']].iloc[:15])
# Out:
#                                                                           normalized_tweet
# 0               [published, new, blog, post, ai, technology, awesome, check, ai, techblog]
# 1                         [excited, share, latest, recipe, creation, try, cooking, foodie]
# 2                                                  [bird, flies, high, sky, nature, peace]
# 3   [thrilling, cricket, match, today, nail, biting, finish, last, ball, six, cricketfans]
# 4       [late, night, studies, tough, cool, worth, end, latenightstudies, hardworkpaysoff]
# 5                                      [loving, fridayfeeling, cannot, wait, fun, weekend]
# 6         [great, time, friends, last, night, feeling, awesome, today, friends, goodtimes]
# 7                                 [loong, day, work, time, relax, watch, movie, chilltime]
# 8                           [tired, weather, cannot, wait, summer, come, readyforsunshine]
# 9             [working, newyearresolution, get, fit, healthy, fitnessgoals, healthyliving]
# 10               [finished, reading, amazing, book, highly, recommend, bookrecommendation]
# 11                  [cooking, dinner, family, tonight, hope, turns, delicious, familytime]
# 12                  [fantastic, day, beach, sun, shining, water, crystal, clear, beachday]
# 13                            [feeling, bit, weather, today, time, rest, recover, sickday]
# 15                             [sorry, cannot, make, party, tonight, great, time, without]

# %% [markdown]
# ## 8.)  <font color = "black">Stemming and Lemmatization:</font><a class = "anchor" id = "lemmatize"></a>

# %%
def lemmatize_token(token):
    return lemmatization_dict.get(token, token)

# Apply lemmatization to each list of tokens in the 'normalized_tweet' column
train_data['lemmatized_tweet'] = train_data['normalized_tweet'].apply(lambda tokens: [lemmatize_token(token) for token in tokens])

test_data['lemmatized_tweet'] = test_data['normalized_tweet'].apply(lambda tokens: [lemmatize_token(token) for token in tokens])

# Print the DataFrame with the lemmatized 'lemm' and 'lemm_sentences' columns
print(train_data[['lemmatized_tweet']])
# Out:
#                                                                              lemmatized_tweet
# 0                  [published, new, blog, post, ai, technology, awesome, check, ai, techblog]
# 1                            [excited, share, latest, recipe, creation, try, cooking, foodie]
# 2                                                     [bird, flies, high, sky, nature, peace]
# 3      [thrilling, cricket, match, today, nail, biting, finish, last, ball, six, cricketfans]
# 4          [late, night, studies, tough, cool, worth, end, latenightstudies, hardworkpaysoff]
# ...                                                                                       ...
# 10034                                                                                   [too]
# 10035                                                            [got, bullied, dillah, help]
# 10036                                                                                   [lol]
# 10037                                               [days, must, look, hardened, good, thing]
# 10038                   [worn, week, sped, soo, fast, gonna, ask, mum, go, movies, desperate]
#
# [10026 rows x 1 columns]

# %%
lemmatization_dict = {
    "abaxially":"abaxial",
    "abjectly":"abject",
    "ably":"able",
    "abnormally":"abnormal",
    "abominably":"abominable",
    "aborad":"aboral",
    "abortively":"abortive",
    "abruptly":"abrupt",
    "absently":"absent",
    "absentmindedly":"absentminded",
    "absolutely":"absolute",
    "abstemiously":"abstemious",
    "abstractedly":"abstracted",
    "abstractly":"abstract",
    "abstrusely":"abstruse",
    "absurdly":"absurd",
    "abundantly":"abundant",
    "abusively":"abusive",
    "academically":"academic",
    "accelerando":"accelerando",
    "accidentally":"accidental",
    "accommodatingly":"accommodating",
    "accurately":"accurate",
    "accusingly":"accusing",
    "acoustically":"acoustic",
    "across_the_board":"across-the-board",
    "actively":"active",
    "actually":"actual",
    "acutely":"acute",
    "adagio":"adagio",
    "adamantly":"adamant",
    "adaxially":"adaxial",
    "adequately":"adequate",
    "adjectivally":"adjectival",
    "administratively":"administrative",
    "admirably":"admirable",
    "adorably":"adorable",
    "adoringly":"adoring",
    "adrift":"adrift",
    "adroitly":"adroit",
    "adulterously":"adulterous",
    "advantageously":"advantageous",
    "adverbially":"adverbial",
    "adversely":"adverse",
    "advertently":"advertent",
    "aerially":"aerial",
    "aesthetically":"aesthetic",
    "affably":"affable",
    "affectedly":"affected",
    "affectingly":"affecting",
    "affectionately":"affectionate",
    "affirmatively":"affirmative",
    "afoot":"afoot",
    "aggravatingly":"aggravating",
    "aggressively":"aggressive",
    "agilely":"agile",
    "agonizingly":"agonizing",
    "agreeably":"agreeable",
    "aimlessly":"aimless",
    "alarmingly":"alarming",
    "alertly":"alert",
    "algebraically":"algebraic",
    "allegedly":"alleged",
    "allegorically":"allegorical",
    "allegretto":"allegretto",
    "allegro":"allegro",
    "alliteratively":"alliterative",
    "alone":"alone",
    "aloof":"aloof",
    "alphabetically":"alphabetical",
    "alternately":"alternate",
    "alternatively":"alternative",
    "altruistically":"altruistic",
    "amazingly":"amazing",
    "ambiguously":"ambiguous",
    "ambitiously":"ambitious",
    "amiably":"amiable",
    "amicably":"amicable",
    "amok":"amok",
    "amorously":"amorous",
    "amply":"ample",
    "amuck":"amuck",
    "amusingly":"amusing",
    "anachronistically":"anachronistic",
    "analogously":"analogous",
    "analytically":"analytic",
    "anarchically":"anarchic",
    "anatomically":"anatomical",
    "anciently":"ancient",
    "andante":"andante",
    "angelically":"angelic",
    "angrily":"angry",
    "animatedly":"animated",
    "anisotropically":"anisotropic",
    "annoyingly":"annoying",
    "annually":"annual",
    "anomalously":"anomalous",
    "anonymously":"anonymous",
    "antagonistically":"antagonistic",
    "antecedently":"antecedent",
    "anteriorly":"anterior",
    "antithetically":"antithetic",
    "anxiously":"anxious",
    "apathetically":"apathetic",
    "apologetically":"apologetic",
    "appallingly":"appalling",
    "apparently":"apparent",
    "appealingly":"appealing",
    "appositively":"appositive",
    "appreciably":"appreciable",
    "appreciatively":"appreciative",
    "apprehensively":"apprehensive",
    "appropriately":"appropriate",
    "approvingly":"approving",
    "aptly":"apt",
    "architecturally":"architectural",
    "archly":"arch",
    "ardently":"ardent",
    "arduously":"arduous",
    "arguably":"arguable",
    "argumentatively":"argumentative",
    "aristocratically":"aristocratic",
    "arithmetically":"arithmetic",
    "arrogantly":"arrogant",
    "artfully":"artful",
    "articulately":"articulate",
    "artificially":"artificial",
    "artistically":"artistic",
    "artlessly":"artless",
    "ascetically":"ascetic",
    "asexually":"asexual",
    "ashamedly":"ashamed",
    "asleep":"asleep",
    "assertively":"assertive",
    "assiduously":"assiduous",
    "assuredly":"assured",
    "astonishingly":"astonishing",
    "astronomically":"astronomic",
    "astutely":"astute",
    "asymptotically":"asymptotic",
    "atonally":"atonal",
    "atrociously":"atrocious",
    "attentively":"attentive",
    "attractively":"attractive",
    "attributively":"attributive",
    "atypically":"atypical",
    "audaciously":"audacious",
    "audibly":"audible",
    "aurally":"aural",
    "auspiciously":"auspicious",
    "austerely":"austere",
    "authentically":"authentic",
    "authoritatively":"authoritative",
    "autocratically":"autocratic",
    "automatically":"automatic",
    "avariciously":"avaricious",
    "avidly":"avid",
    "avowedly":"avowed",
    "awfully":"awful",
    "awkwardly":"awkward",
    "axially":"axial",
    "axiomatically":"axiomatic",
    "backstage":"backstage",
    "bacterially":"bacterial",
    "badly":"bad",
    "baldly":"bald",
    "balefully":"baleful",
    "balmily":"balmy",
    "banefully":"baneful",
    "banteringly":"bantering",
    "barbarously":"barbarous",
    "barefacedly":"barefaced",
    "barely":"bare",
    "basely":"base",
    "bashfully":"bashful",
    "bawdily":"bawdy",
    "beastly":"beastly",
    "beautifully":"beautiful",
    "becomingly":"becoming",
    "befittingly":"befitting",
    "belatedly":"belated",
    "believably":"believable",
    "belligerently":"belligerent",
    "beneficially":"beneficial",
    "benevolently":"benevolent",
    "benignantly":"benignant",
    "benignly":"benign",
    "beseechingly":"beseeching",
    "bestially":"bestial",
    "bewilderedly":"bewildered",
    "bewitchingly":"bewitching",
    "biannually":"biannual",
    "biennially":"biennial",
    "bilaterally":"bilateral",
    "bilingually":"bilingual",
    "bimonthly":"bimonthly",
    "binaurally":"binaural",
    "biochemically":"biochemical",
    "biologically":"biological",
    "biradially":"biradial",
    "bitingly":"biting",
    "bitterly":"bitter",
    "biweekly":"biweekly",
    "biyearly":"biyearly",
    "blamelessly":"blameless",
    "blandly":"bland",
    "blankly":"blank",
    "blasphemously":"blasphemous",
    "blatantly":"blatant",
    "bleakly":"bleak",
    "blessedly":"blessed",
    "blindly":"blind",
    "blissfully":"blissful",
    "blithely":"blithe",
    "bloodily":"bloody",
    "bloodlessly":"bloodless",
    "bluffly":"bluff",
    "bluntly":"blunt",
    "boastfully":"boastful",
    "bodily":"bodily",
    "boisterously":"boisterous",
    "boldly":"bold",
    "bombastically":"bombastic",
    "bonnily":"bonny",
    "boorishly":"boorish",
    "boringly":"boring",
    "boundlessly":"boundless",
    "bounteously":"bounteous",
    "bountifully":"bountiful",
    "boyishly":"boyish",
    "boylike":"boylike",
    "brashly":"brash",
    "bravely":"brave",
    "brazenly":"brazen",
    "breathlessly":"breathless",
    "breezily":"breezy",
    "briefly":"brief",
    "brightly":"bright",
    "brilliantly":"brilliant",
    "briskly":"brisk",
    "broad-mindedly":"broad-minded",
    "broadly":"broad",
    "brotherly":"brotherly",
    "brusquely":"brusque",
    "brutishly":"brutish",
    "bumptiously":"bumptious",
    "buoyantly":"buoyant",
    "bureaucratically":"bureaucratic",
    "busily":"busy",
    "buxomly":"buxom",
    "cagily":"cagy",
    "calculatingly":"calculating",
    "callously":"callous",
    "calmly":"calm",
    "calumniously":"calumnious",
    "candidly":"candid",
    "cannily":"canny",
    "canonically":"canonical",
    "cantankerously":"cantankerous",
    "capably":"capable",
    "capriciously":"capricious",
    "captiously":"captious",
    "captivatingly":"captivating",
    "carefully":"careful",
    "carelessly":"careless",
    "carnally":"carnal",
    "casually":"casual",
    "catalytically":"catalytic",
    "catastrophically":"catastrophic",
    "categorically":"categorical",
    "caudal":"caudal",
    "causally":"causal",
    "caustically":"caustic",
    "cautiously":"cautious",
    "cavalierly":"cavalier",
    "ceaselessly":"ceaseless",
    "centennially":"centennial",
    "centrally":"central",
    "cerebrally":"cerebral",
    "ceremonially":"ceremonial",
    "ceremoniously":"ceremonious",
    "certainly":"certain",
    "chaotically":"chaotic",
    "characteristically":"characteristic",
    "charily":"chary",
    "charitably":"charitable",
    "charmingly":"charming",
    "chastely":"chaste",
    "chattily":"chatty",
    "cheaply":"cheap",
    "cheekily":"cheeky",
    "cheerily":"cheery",
    "chemically":"chemical",
    "chiefly":"chief",
    "childishly":"childish",
    "chintzily":"chintzy",
    "chivalrously":"chivalrous",
    "chorally":"choral",
    "chromatically":"chromatic",
    "chromatographically":"chromatographic",
    "chronically":"chronic",
    "chronologically":"chronological",
    "churlishly":"churlish",
    "circularly":"circular",
    "circumspectly":"circumspect",
    "circumstantially":"circumstantial",
    "civilly":"civil",
    "clammily":"clammy",
    "clamorously":"clamorous",
    "clannishly":"clannish",
    "classically":"classical",
    "cleanly":"clean",
    "clearly":"clear",
    "cleverly":"clever",
    "climatically":"climatic",
    "clinically":"clinical",
    "cliquishly":"cliquish",
    "clockwise":"clockwise",
    "closely":"close",
    "cloyingly":"cloying",
    "clumsily":"clumsy",
    "coarsely":"coarse",
    "cognitively":"cognitive",
    "coherently":"coherent",
    "coincidentally":"coincidental",
    "coincidently":"coincident",
    "cold-bloodedly":"cold-blooded",
    "coldly":"cold",
    "collectedly":"collected",
    "collectively":"collective",
    "colloidally":"colloidal",
    "colloquially":"colloquial",
    "combatively":"combative",
    "comfortably":"comfortable",
    "comfortingly":"comforting",
    "comically":"comical",
    "commendable":"commendable",
    "commensally":"commensal",
    "commercially":"commercial",
    "commonly":"common",
    "communally":"communal",
    "compactly":"compact",
    "comparably":"comparable",
    "comparatively":"comparative",
    "compassionately":"compassionate",
    "compatibly":"compatible",
    "competently":"competent",
    "competitively":"competitive",
    "complacently":"complacent",
    "complainingly":"complaining",
    "completely":"complete",
    "complexly":"complex",
    "composedly":"composed",
    "comprehensively":"comprehensive",
    "compulsively":"compulsive",
    "compulsorily":"compulsory",
    "computationally":"computational",
    "con_brio":"con_brio",
    "concavely":"concave",
    "conceitedly":"conceited",
    "conceivably":"conceivable",
    "conceptually":"conceptual",
    "concisely":"concise",
    "conclusively":"conclusive",
    "concretely":"concrete",
    "concurrently":"concurrent",
    "condescendingly":"condescending",
    "confidentially":"confidential",
    "confidently":"confident",
    "confidingly":"confiding",
    "conformably":"conformable",
    "confoundedly":"confounded",
    "confusedly":"confused",
    "confusingly":"confusing",
    "congenially":"congenial",
    "conically":"conical",
    "conjecturally":"conjectural",
    "conjointly":"conjoint",
    "conjugally":"conjugal",
    "connubial":"connubial",
    "conscientiously":"conscientious",
    "consciously":"conscious",
    "consecutive":"consecutive",
    "consequently":"consequent",
    "considerably":"considerable",
    "considerately":"considerate",
    "consistently":"consistent",
    "consolingly":"consoling",
    "conspicuously":"conspicuous",
    "constantly":"constant",
    "constitutionally":"constitutional",
    "constrainedly":"constrained",
    "constructively":"constructive",
    "contagiously":"contagious",
    "contemporaneously":"contemporaneous",
    "contemptibly":"contemptible",
    "contemptuously":"contemptuous",
    "contentedly":"contented",
    "contextually":"contextual",
    "continually":"continual",
    "continuously":"continuous",
    "contractually":"contractual",
    "contradictorily":"contradictory",
    "contrarily":"contrary",
    "contrastingly":"contrasting",
    "contritely":"contrite",
    "controversially":"controversial",
    "contumaciously":"contumacious",
    "contumeliously":"contumelious",
    "conveniently":"convenient",
    "conventionally":"conventional",
    "conversationally":"conversational",
    "conversely":"converse",
    "convexly":"convex",
    "convincingly":"convincing",
    "convivially":"convivial",
    "convulsively":"convulsive",
    "coolly":"cool",
    "cooperatively":"cooperative",
    "coordinately":"coordinate",
    "copiously":"copious",
    "coquettishly":"coquettish",
    "cordially":"cordial",
    "corruptly":"corrupt",
    "cortically":"cortical",
    "cosmetically":"cosmetic",
    "coterminously":"coterminous",
    "counteractively":"counteractive",
    "counterclockwise":"counterclockwise",
    "counterintuitively":"counterintuitive",
    "courageously":"courageous",
    "courteously":"courteous",
    "covertly":"covert",
    "covetously":"covetous",
    "coyly":"coy",
    "cozily":"cozy",
    "craftily":"crafty",
    "crazily":"crazy",
    "creakily":"creaky",
    "creatively":"creative",
    "credibly":"credible",
    "creditably":"creditable",
    "credulously":"credulous",
    "criminally":"criminal",
    "crisply":"crisp",
    "critically":"critical",
    "crookedly":"crooked",
    "cross-linguistically":"cross-linguistic",
    "crossly":"cross",
    "crosstown":"crosstown",
    "crucially":"crucial",
    "crudely":"crude",
    "cruelly":"cruel",
    "crushingly":"crushing",
    "cryptically":"cryptic",
    "cryptographically":"cryptographic",
    "culpably":"culpable",
    "culturally":"cultural",
    "cum_laude":"cum_laude",
    "cumulatively":"cumulative",
    "cunningly":"cunning",
    "curiously":"curious",
    "currently":"current",
    "currishly":"currish",
    "cursedly":"cursed",
    "cursively":"cursive",
    "cursorily":"cursory",
    "curtly":"curt",
    "curvaceously":"curvaceous",
    "cussedly":"cussed",
    "customarily":"customary",
    "cutely":"cute",
    "cuttingly":"cutting",
    "cynically":"cynical",
    "cytophotometrically":"cytophotometric",
    "cytoplasmically":"cytoplasmic",
    "daftly":"daft",
    "daily":"daily",
    "daintily":"dainty",
    "damnably":"damnable",
    "damply":"damp",
    "dandily":"dandy",
    "dangerously":"dangerous",
    "daringly":"daring",
    "darkly":"dark",
    "dashingly":"dashing",
    "dauntingly":"daunting",
    "dauntlessly":"dauntless",
    "dazedly":"dazed",
    "dazzlingly":"dazzling",
    "deadly":"dead",
    "dearly":"dear",
    "deceitfully":"deceitful",
    "decently":"decent",
    "deceptively":"deceptive",
    "decidedly":"decided",
    "decipherably":"decipherable",
    "decisively":"decisive",
    "decoratively":"decorative",
    "decorously":"decorous",
    "deep":"deep",
    "defectively":"defective",
    "defenceless":"defenceless",
    "defenseless":"defenseless",
    "defensively":"defensive",
    "deferentially":"deferential",
    "defiantly":"defiant",
    "deftly":"deft",
    "dejectedly":"dejected",
    "deliberately":"deliberate",
    "delicately":"delicate",
    "deliciously":"delicious",
    "delightedly":"delighted",
    "delightfully":"delightful",
    "deliriously":"delirious",
    "delusively":"delusive",
    "demandingly":"demanding",
    "demeaningly":"demeaning",
    "dementedly":"demented",
    "democratically":"democratic",
    "demonstrably":"demonstrable",
    "demonstratively":"demonstrative",
    "demurely":"demure",
    "denominationally":"denominational",
    "densely":"dense",
    "departmentally":"departmental",
    "dependably":"dependable",
    "deplorably":"deplorable",
    "deprecatively":"deprecative",
    "depressingly":"depressing",
    "derisively":"derisive",
    "descriptively":"descriptive",
    "despairingly":"despairing",
    "desperately":"desperate",
    "despicably":"despicable",
    "despitefully":"despiteful",
    "despondently":"despondent",
    "destructively":"destructive",
    "determinedly":"determined",
    "detestably":"detestable",
    "detrimentally":"detrimental",
    "developmentally":"developmental",
    "devilishly":"devilish",
    "deviously":"devious",
    "devotedly":"devoted",
    "devoutly":"devout",
    "dexterously":"dexterous",
    "dextrously":"dextrous",
    "diabolically":"diabolic",
    "diagonally":"diagonal",
    "diagrammatically":"diagrammatic",
    "dialectically":"dialectic",
    "diametrically":"diametric",
    "dichotomously":"dichotomous",
    "dictatorially":"dictatorial",
    "didactically":"didactic",
    "differentially":"differential",
    "differently":"different",
    "diffidently":"diffident",
    "diffusely":"diffuse",
    "digitally":"digital",
    "digitately":"digitate",
    "diligently":"diligent",
    "dimly":"dim",
    "dingily":"dingy",
    "directly":"direct",
    "direfully":"direful",
    "dirtily":"dirty",
    "disadvantageously":"disadvantageous",
    "disagreeably":"disagreeable",
    "disappointedly":"disappointed",
    "disappointingly":"disappointing",
    "disastrously":"disastrous",
    "disbelievingly":"disbelieving",
    "disconcertingly":"disconcerting",
    "disconsolately":"disconsolate",
    "discontentedly":"discontented",
    "discordantly":"discordant",
    "discouragingly":"discouraging",
    "discourteously":"discourteous",
    "discreditably":"discreditable",
    "discursively":"discursive",
    "disdainfully":"disdainful",
    "disgracefully":"disgraceful",
    "disgustedly":"disgusted",
    "disgustingly":"disgusting",
    "dishonestly":"dishonest",
    "dishonorably":"dishonorable",
    "disingenuously":"disingenuous",
    "disinterestedly":"disinterested",
    "disjointedly":"disjointed",
    "disloyally":"disloyal",
    "dismally":"dismal",
    "disobediently":"disobedient",
    "disparagingly":"disparaging",
    "dispassionately":"dispassionate",
    "dispiritedly":"dispirited",
    "displeasingly":"displeasing",
    "disproportionately":"disproportionate",
    "disputatiously":"disputatious",
    "disquietingly":"disquieting",
    "disreputably":"disreputable",
    "disrespectfully":"disrespectful",
    "disruptively":"disruptive",
    "dissolutely":"dissolute",
    "distally":"distal",
    "distantly":"distant",
    "distastefully":"distasteful",
    "distinctively":"distinctive",
    "distinctly":"distinct",
    "distractedly":"distracted",
    "distressfully":"distressful",
    "distressingly":"distressing",
    "distributively":"distributive",
    "distributively":"distributed",
    "distrustfully":"distrustful",
    "disturbingly":"disturbing",
    "diversely":"diverse",
    "divertingly":"diverting",
    "divinely":"divine",
    "dizzily":"dizzy",
    "doctrinally":"doctrinal",
    "doggedly":"dogged",
    "dogmatically":"dogmatic",
    "dolefully":"doleful",
    "doltishly":"doltish",
    "domestically":"domestic",
    "domineeringly":"domineering",
    "dorsally":"dorsal",
    "dorsoventrally":"dorsoventral",
    "dottily":"dotty",
    "doubly":"double",
    "doubtfully":"doubtful",
    "dourly":"dour",
    "dowdily":"dowdy",
    "drably":"drab",
    "draggingly":"dragging",
    "dramatically":"dramatic",
    "drastically":"drastic",
    "dreadfully":"dreadful",
    "dreamily":"dreamy",
    "drearily":"dreary",
    "drily":"dry",
    "drippily":"drippy",
    "droopingly":"drooping",
    "drowsily":"drowsy",
    "drunkenly":"drunken",
    "dubiously":"dubious",
    "dully":"dull",
    "dumbly":"dumb",
    "dutifully":"dutiful",
    "dynamically":"dynamic",
    "eagerly":"eager",
    "early":"early",
    "earnestly":"earnest",
    "easterly":"east",
    "easy":"easy",
    "ebulliently":"ebullient",
    "eccentrically":"eccentric",
    "ecclesiastically":"ecclesiastic",
    "ecologically":"ecological",
    "economically":"economic",
    "ecstatically":"ecstatic",
    "editorially":"editorial",
    "educationally":"educational",
    "effectively":"effective",
    "efficaciously":"efficacious",
    "efficiently":"efficient",
    "effortlessly":"effortless",
    "effusively":"effusive",
    "egotistically":"egotistic",
    "elaborately":"elaborate",
    "electrically":"electric",
    "electronically":"electronic",
    "electrostatically":"electrostatic",
    "elegantly":"elegant",
    "elementarily":"elementary",
    "eloquently":"eloquent",
    "embarrassingly":"embarrassing",
    "eminently":"eminent",
    "emotionally":"emotional",
    "empathetically":"empathetic",
    "emphatically":"emphatic",
    "empirically":"empirical",
    "emulously":"emulous",
    "enchantingly":"enchanting",
    "encouragingly":"encouraging",
    "endearingly":"endearing",
    "endlessly":"endless",
    "endogenously":"endogenous",
    "enduringly":"enduring",
    "energetically":"energetic",
    "engagingly":"engaging",
    "enigmatically":"enigmatic",
    "enjoyably":"enjoyable",
    "enormously":"enormous",
    "enterprisingly":"enterprising",
    "enthrallingly":"enthralling",
    "enthusiastically":"enthusiastic",
    "entirely":"entire",
    "enviably":"enviable",
    "enviously":"envious",
    "environmentally":"environmental",
    "episodically":"episodic",
    "equably":"equable",
    "equally":"equal",
    "equitably":"equitable",
    "equivocally":"equivocal",
    "erectly":"erect",
    "erotically":"erotic",
    "erratically":"erratic",
    "erroneously":"erroneous",
    "eruditely":"erudite",
    "eschatologically":"eschatological",
    "especially":"especial",
    "essentially":"essential",
    "esthetically":"esthetic",
    "eternally":"eternal",
    "ethically":"ethical",
    "ethnically":"ethnic",
    "euphemistically":"euphemistic",
    "evasively":"evasive",
    "evenly":"even",
    "eventually":"eventual",
    "everlastingly":"everlasting",
    "evidently":"evident",
    "evilly":"evil",
    "evolutionarily":"evolutionary",
    "exactly":"exact",
    "exasperatingly":"exasperating",
    "excellently":"excellent",
    "exceptionally":"exceptional",
    "excessively":"excessive",
    "excitedly":"excited",
    "excitingly":"exciting",
    "exclusively":"exclusive",
    "excruciatingly":"excruciating",
    "exorbitantly":"exorbitant",
    "expansively":"expansive",
    "expectantly":"expectant",
    "expediently":"expedient",
    "expeditiously":"expeditious",
    "expensively":"expensive",
    "experimentally":"experimental",
    "expertly":"expert",
    "explicitly":"explicit",
    "explosively":"explosive",
    "exponentially":"exponential",
    "expressly":"express",
    "exquisitely":"exquisite",
    "extemporaneously":"extemporaneous",
    "extemporarily":"extemporary",
    "extensively":"extensive",
    "externally":"external",
    "extortionately":"extortionate",
    "extraordinarily":"extraordinary",
    "extravagantly":"extravagant",
    "extremely":"extreme",
    "exuberantly":"exuberant",
    "exultantly":"exultant",
    "exultingly":"exulting",
    "facetiously":"facetious",
    "facially":"facial",
    "factually":"factual",
    "faddily":"faddy",
    "faddishly":"faddish",
    "faintly":"faint",
    "fairly":"fair",
    "faithfully":"faithful",
    "faithlessly":"faithless",
    "falsely":"false",
    "falteringly":"faltering",
    "familiarly":"familiar",
    "famously":"famous",
    "fanatically":"fanatic",
    "fancifully":"fanciful",
    "farcically":"farcical",
    "fascinatingly":"fascinating",
    "fashionably":"fashionable",
    "fast":"fast",
    "fastidiously":"fastidious",
    "fatally":"fatal",
    "fatefully":"fateful",
    "fatuously":"fatuous",
    "faultily":"faulty",
    "faultlessly":"faultless",
    "favorably":"favorable",
    "fearfully":"fearful",
    "fearlessly":"fearless",
    "fearsomely":"fearsome",
    "feasibly":"feasible",
    "fecklessly":"feckless",
    "federally":"federal",
    "feebly":"feeble",
    "felicitously":"felicitous",
    "ferociously":"ferocious",
    "fervently":"fervent",
    "fervidly":"fervid",
    "feudally":"feudal",
    "feverishly":"feverish",
    "fictitiously":"fictitious",
    "fiendishly":"fiendish",
    "fiercely":"fierce",
    "fierily":"fiery",
    "fifthly":"fifth",
    "figuratively":"figurative",
    "filthily":"filthy",
    "finally":"final",
    "financially":"financial",
    "finely":"fine",
    "finitely":"finite",
    "firmly":"firm",
    "fiscally":"fiscal",
    "fishily":"fishy",
    "fitfully":"fitful",
    "fitly":"fit",
    "fixedly":"fixed",
    "flabbily":"flabby",
    "flagrantly":"flagrant",
    "flamboyantly":"flamboyant",
    "flashily":"flashy",
    "flatly":"flat",
    "flawlessly":"flawless",
    "fleetly":"fleet",
    "flexibly":"flexible",
    "flimsily":"flimsy",
    "flippantly":"flippant",
    "flirtatiously":"flirtatious",
    "floridly":"florid",
    "fluently":"fluent",
    "focally":"focal",
    "fondly":"fond",
    "foolishly":"foolish",
    "forbiddingly":"forbidding",
    "forcefully":"forceful",
    "forcibly":"forcible",
    "forgetfully":"forgetful",
    "forgivably":"forgivable",
    "forgivingly":"forgiving",
    "forlornly":"forlorn",
    "formally":"formal",
    "formidably":"formidable",
    "formlessly":"formless",
    "forte":"forte",
    "fortissimo":"fortissimo",
    "fortnightly":"fortnightly",
    "fortuitously":"fortuitous",
    "fortunately":"fortunate",
    "foully":"foul",
    "fourfold":"fourfold",
    "fourth":"fourth",
    "foxily":"foxy",
    "fractiously":"fractious",
    "frankly":"frank",
    "frantically":"frantic",
    "fraternally":"fraternal",
    "fraudulently":"fraudulent",
    "freakishly":"freakish",
    "freely":"free",
    "frenetically":"frenetic",
    "frenziedly":"frenzied",
    "frequently":"frequent",
    "freshly":"fresh",
    "fretfully":"fretful",
    "frighteningly":"frightening",
    "frigidly":"frigid",
    "friskily":"frisky",
    "frivolously":"frivolous",
    "frontally":"frontal",
    "frostily":"frosty",
    "frothily":"frothy",
    "frowningly":"frowning",
    "frugally":"frugal",
    "fruitlessly":"fruitless",
    "frumpily":"frumpy",
    "frumpishly":"frumpish",
    "fugally":"fugal",
    "fully":"full",
    "fulsomely":"fulsome",
    "functionally":"functional",
    "fundamentally":"fundamental",
    "funnily":"funny",
    "furiously":"furious",
    "furtively":"furtive",
    "fussily":"fussy",
    "futilely":"futile",
    "gaily":"gay",
    "gainfully":"gainful",
    "gallantly":"gallant",
    "gamely":"game",
    "garishly":"garish",
    "garrulously":"garrulous",
    "gaudily":"gaudy",
    "genealogically":"genealogical",
    "generally":"general",
    "generically":"generic",
    "generously":"generous",
    "genetically":"genetic",
    "genially":"genial",
    "genteelly":"genteel",
    "gently":"gentle",
    "genuinely":"genuine",
    "geographically":"geographic",
    "geologically":"geological",
    "geometrically":"geometric",
    "geothermally":"geothermal",
    "giddily":"giddy",
    "gingerly":"gingerly",
    "girlishly":"girlish",
    "glacially":"glacial",
    "gladly":"glad",
    "glaringly":"glaring",
    "gleefully":"gleeful",
    "glibly":"glib",
    "globally":"global",
    "gloomily":"gloomy",
    "gloriously":"glorious",
    "glossily":"glossy",
    "gloweringly":"glowering",
    "glowingly":"glowing",
    "glumly":"glum",
    "gluttonously":"gluttonous",
    "good-naturedly":"good-natured",
    "gorgeously":"gorgeous",
    "governmentally":"governmental",
    "gracefully":"graceful",
    "gracelessly":"graceless",
    "graciously":"gracious",
    "gradually":"gradual",
    "grammatically":"grammatical",
    "grandiloquently":"grandiloquent",
    "grandiosely":"grandiose",
    "grandly":"grand",
    "graphically":"graphic",
    "gratefully":"grateful",
    "gratifyingly":"gratifying",
    "gratingly":"grating",
    "gratuitously":"gratuitous",
    "gravely":"grave",
    "gravitationally":"gravitational",
    "grayly":"gray",
    "greasily":"greasy",
    "greatly":"great",
    "greedily":"greedy",
    "greenly":"green",
    "gregariously":"gregarious",
    "greyly":"grey",
    "grievously":"grievous",
    "grimly":"grim",
    "gropingly":"groping",
    "grossly":"gross",
    "grotesquely":"grotesque",
    "grouchily":"grouchy",
    "grubbily":"grubby",
    "grudgingly":"grudging",
    "gruesomely":"gruesome",
    "gruffly":"gruff",
    "grumpily":"grumpy",
    "grungily":"grungy",
    "guardedly":"guarded",
    "guiltily":"guilty",
    "gushingly":"gushing",
    "gutturally":"guttural",
    "habitually":"habitual",
    "haggardly":"haggard",
    "half":"half",
    "half-and-half":"half-and-half",
    "half-heartedly":"halfhearted",
    "half-hourly":"half-hourly",
    "half-yearly":"half-yearly",
    "handily":"handy",
    "handsomely":"handsome",
    "haphazardly":"haphazard",
    "happily":"happy",
    "haptically":"haptic",
    "hard":"hard",
    "hard":"hardened",
    "harmfully":"harmful",
    "harmlessly":"harmless",
    "harmonically":"harmonic",
    "harmoniously":"harmonious",
    "harshly":"harsh",
    "hastily":"hasty",
    "hatefully":"hateful",
    "haughtily":"haughty",
    "hazardously":"hazardous",
    "hazily":"hazy",
    "head-to-head":"head-to-head",
    "headlong":"headlong",
    "healthily":"healthy",
    "heartily":"hearty",
    "heartlessly":"heartless",
    "heatedly":"heated",
    "heavily":"heavy",
    "hebdomadally":"hebdomadal",
    "hectically":"hectic",
    "heedfully":"heedful",
    "heedlessly":"heedless",
    "heinously":"heinous",
    "helpfully":"helpful",
    "helplessly":"helpless",
    "hermetically":"hermetic",
    "heroically":"heroic",
    "hesitantly":"hesitant",
    "hideously":"hideous",
    "hierarchically":"hierarchical",
    "hieroglyphically":"hieroglyphic",
    "high-handedly":"high-handed",
    "high-mindedly":"high-minded",
    "highly":"high",
    "hilariously":"hilarious",
    "hinderingly":"hindering",
    "histologically":"histological",
    "historically":"historical",
    "historically":"historic",
    "hoarsely":"hoarse",
    "homeostatically":"homeostatic",
    "homogeneously":"homogeneous",
    "honestly":"honest",
    "honorably":"honorable",
    "hopefully":"hopeful",
    "hopelessly":"hopeless",
    "horizontally":"horizontal",
    "horribly":"horrible",
    "horridly":"horrid",
    "horrifyingly":"horrifying",
    "horticulturally":"horticultural",
    "hospitably":"hospitable",
    "hostilely":"hostile",
    "hotly":"hot",
    "hourly":"hourly",
    "huffily":"huffy",
    "humanely":"humane",
    "humanly":"human",
    "humbly":"humble",
    "humiliatingly":"humiliating",
    "humorlessly":"humorless",
    "humorously":"humorous",
    "hungrily":"hungry",
    "hurriedly":"hurried",
    "huskily":"husky",
    "hydraulically":"hydraulic",
    "hygienically":"hygienic",
    "hyperbolically":"hyperbolic",
    "hypnotically":"hypnotic",
    "hypocritically":"hypocritical",
    "hypothalamically":"hypothalamic",
    "hypothetically":"hypothetical",
    "hysterically":"hysterical",
    "icily":"icy",
    "ideally":"ideal",
    "identically":"identical",
    "identifiably":"identifiable",
    "ideographically":"ideographic",
    "idiomatically":"idiomatic",
    "idiotically":"idiotic",
    "idly":"idle",
    "idolatrously":"idolatrous",
    "idyllically":"idyllic",
    "ignobly":"ignoble",
    "ignominiously":"ignominious",
    "ignorantly":"ignorant",
    "illegally":"illegal",
    "illegibly":"illegible",
    "illegitimately":"illegitimate",
    "illiberally":"illiberal",
    "illicitly":"illicit",
    "illogically":"illogical",
    "illustriously":"illustrious",
    "imaginatively":"imaginative",
    "immaculately":"immaculate",
    "immaturely":"immature",
    "immeasurably":"immeasurable",
    "immediately":"immediate",
    "immensely":"immense",
    "imminently":"imminent",
    "immoderately":"immoderate",
    "immodestly":"immodest",
    "immorally":"immoral",
    "immovably":"immovable",
    "immunologically":"immunological",
    "immutably":"immutable",
    "impartially":"impartial",
    "impassively":"impassive",
    "impatiently":"impatient",
    "impeccably":"impeccable",
    "impenitently":"impenitent",
    "imperatively":"imperative",
    "imperceptibly":"imperceptible",
    "imperfectly":"imperfect",
    "imperially":"imperial",
    "imperiously":"imperious",
    "impermissibly":"impermissible",
    "impersonally":"impersonal",
    "impertinently":"impertinent",
    "impetuously":"impetuous",
    "impiously":"impious",
    "impishly":"impish",
    "implausibly":"implausible",
    "implicitly":"implicit",
    "impolitely":"impolite",
    "importantly":"important",
    "importunately":"importunate",
    "imposingly":"imposing",
    "impossibly":"impossible",
    "impotently":"impotent",
    "impracticably":"impracticable",
    "imprecisely":"imprecise",
    "impregnably":"impregnable",
    "impressively":"impressive",
    "improbably":"improbable",
    "improperly":"improper",
    "improvidently":"improvident",
    "imprudently":"imprudent",
    "impudently":"impudent",
    "impulsively":"impulsive",
    "in_vitro":"in_vitro",
    "in_vivo":"in_vivo",
    "inaccessibly":"inaccessible",
    "inaccurately":"inaccurate",
    "inadequately":"inadequate",
    "inadvertently":"inadvertent",
    "inadvisably":"inadvisable",
    "inalienably":"inalienable",
    "inanely":"inane",
    "inappropriately":"inappropriate",
    "inarticulately":"inarticulate",
    "inattentively":"inattentive",
    "inaudibly":"inaudible",
    "inaugurally":"inaugural",
    "inauspiciously":"inauspicious",
    "incautiously":"incautious",
    "incessantly":"incessant",
    "incestuously":"incestuous",
    "incidentally":"incidental",
    "incisively":"incisive",
    "incoherently":"incoherent",
    "incomparably":"incomparable",
    "incompatibly":"incompatible",
    "incompetently":"incompetent",
    "incompletely":"incomplete",
    "inconceivably":"inconceivable",
    "inconclusively":"inconclusive",
    "incongruously":"incongruous",
    "inconsequently":"inconsequent",
    "inconsiderately":"inconsiderate",
    "inconsistently":"inconsistent",
    "inconspicuously":"inconspicuous",
    "incontrovertibly":"incontrovertible",
    "inconveniently":"inconvenient",
    "incorrectly":"incorrect",
    "increasingly":"increasing",
    "incredibly":"incredible",
    "incredulously":"incredulous",
    "incriminatingly":"incriminating",
    "incurably":"incurable",
    "indecently":"indecent",
    "indecisively":"indecisive",
    "indecorously":"indecorous",
    "indefatigably":"indefatigable",
    "indefinitely":"indefinite",
    "indelibly":"indelible",
    "independently":"independent",
    "indescribably":"indescribable",
    "indeterminably":"indeterminable",
    "indifferently":"indifferent",
    "indigenously":"indigenous",
    "indignantly":"indignant",
    "indirectly":"indirect",
    "indiscreetly":"discreet",
    "indiscriminately":"indiscriminate",
    "indistinctly":"indistinct",
    "individualistically":"individualistic",
    "individually":"individual",
    "indolently":"indolent",
    "indubitably":"indubitable",
    "indulgently":"indulgent",
    "industrially":"industrial",
    "industriously":"industrious",
    "ineffably":"ineffable",
    "ineffectively":"ineffective",
    "ineffectually":"ineffectual",
    "inefficaciously":"inefficacious",
    "inefficiently":"inefficient",
    "inelegantly":"inelegant",
    "ineluctably":"ineluctable",
    "ineptly":"inept",
    "inequitably":"inequitable",
    "inescapably":"inescapable",
    "inevitably":"inevitable",
    "inexactly":"inexact",
    "inexcusably":"inexcusable",
    "inexcusably":"excusable",
    "inexorably":"inexorable",
    "inexpediently":"inexpedient",
    "inexpertly":"inexpert",
    "inextricably":"inextricable",
    "infectiously":"infectious",
    "infelicitously":"infelicitous",
    "infernally":"infernal",
    "infinitely":"infinite",
    "inflexibly":"inflexible",
    "influentially":"influential",
    "informally":"informal",
    "informatively":"informative",
    "infrequently":"infrequent",
    "ingenuously":"ingenuous",
    "ingloriously":"inglorious",
    "ingratiatingly":"ingratiating",
    "inherently":"inherent",
    "inhospitably":"inhospitable",
    "inhumanely":"inhumane",
    "inimitably":"inimitable",
    "iniquitously":"iniquitous",
    "initially":"initial",
    "injudiciously":"injudicious",
    "injuriously":"injurious",
    "innately":"innate",
    "innocently":"innocent",
    "inoffensively":"inoffensive",
    "inopportunely":"inopportune",
    "inordinately":"inordinate",
    "inorganically":"inorganic",
    "inquiringly":"inquiring",
    "inquisitively":"inquisitive",
    "insanely":"insane",
    "insatiably":"insatiable",
    "inscriptively":"inscriptive",
    "inscrutably":"inscrutable",
    "insecticidally":"insecticidal",
    "insecurely":"insecure",
    "insensately":"insensate",
    "insensibly":"insensible",
    "insensitively":"insensitive",
    "inseparably":"inseparable",
    "insidiously":"insidious",
    "insignificantly":"insignificant",
    "insincerely":"insincere",
    "insipidly":"insipid",
    "insistently":"insistent",
    "insolently":"insolent",
    "inspirationally":"inspirational",
    "instantaneously":"instantaneous",
    "instinctively":"instinctive",
    "institutionally":"institutional",
    "instructively":"instructive",
    "insufficiently":"insufficient",
    "insultingly":"insulting",
    "insuperably":"insuperable",
    "integrally":"integral",
    "intellectually":"intellectual",
    "intelligently":"intelligent",
    "intelligibly":"intelligible",
    "intemperately":"intemperate",
    "intensely":"intense",
    "intentionally":"intentional",
    "intently":"intent",
    "interchangeably":"interchangeable",
    "interdepartmental":"interdepartmental",
    "interestingly":"interesting",
    "interminably":"interminable",
    "intermittently":"intermittent",
    "internally":"internal",
    "internationally":"international",
    "interracially":"interracial",
    "interrogatively":"interrogative",
    "intimately":"intimate",
    "intolerably":"tolerable",
    "intolerantly":"intolerant",
    "intractably":"intractable",
    "intradermally":"intradermal",
    "intramuscularly":"intramuscular",
    "intransitively":"intransitive",
    "intravenously":"intravenous",
    "intrepidly":"intrepid",
    "intricately":"intricate",
    "intrinsically":"intrinsic",
    "intuitively":"intuitive",
    "invariably":"invariable",
    "inventively":"inventive",
    "invidiously":"invidious",
    "invincibly":"invincible",
    "invisibly":"invisible",
    "invitingly":"inviting",
    "involuntarily":"involuntary",
    "inwardly":"inward",
    "irately":"irate",
    "ironically":"ironical",
    "irrationally":"irrational",
    "irregularly":"irregular",
    "irrelevantly":"irrelevant",
    "irreparably":"irreparable",
    "irreproachably":"irreproachable",
    "irresistibly":"irresistible",
    "irresolutely":"irresolute",
    "irresponsibly":"irresponsible",
    "irretrievably":"irretrievable",
    "irreverently":"irreverent",
    "irreversibly":"irreversible",
    "irrevocably":"irrevocable",
    "irritably":"irritable",
    "irritatingly":"irritating",
    "isotropically":"isotropic",
    "jaggedly":"jagged",
    "jarringly":"jarring",
    "jauntily":"jaunty",
    "jealously":"jealous",
    "jeeringly":"jeering",
    "jejunely":"jejune",
    "jerkily":"jerky",
    "jestingly":"jesting",
    "jocosely":"jocose",
    "jocular":"jocular",
    "jointly":"joint",
    "jokingly":"joking",
    "journalistically":"journalistic",
    "jovially":"jovial",
    "joyfully":"joyful",
    "joylessly":"joyless",
    "joyously":"joyous",
    "jubilantly":"jubilant",
    "judicially":"judicial",
    "jurisprudentially":"jurisprudential",
    "justifiably":"justifiable",
    "justly":"just",
    "keenly":"keen",
    "killingly":"killing",
    "kindly":"kind",
    "kinesthetically":"kinesthetic",
    "knavishly":"knavish",
    "knowingly":"knowing",
    "laboriously":"laborious",
    "lackadaisically":"lackadaisical",
    "laconically":"laconic",
    "lamely":"lame",
    "languidly":"languid",
    "languorously":"languorous",
    "largo":"largo",
    "lasciviously":"lascivious",
    "last":"last",
    "late":"late",
    "later":"later",
    "laterally":"lateral",
    "laudably":"laudable",
    "laughably":"laughable",
    "lavishly":"lavish",
    "lawfully":"lawful",
    "laxly":"lax",
    "lazily":"lazy",
    "learnedly":"learned",
    "legally":"legal",
    "legibly":"legible",
    "legislatively":"legislative",
    "legitimately":"legitimate",
    "leisurely":"leisurely",
    "lengthily":"lengthy",
    "leniently":"lenient",
    "lethargically":"lethargic",
    "lewdly":"lewd",
    "lexically":"lexical",
    "liberally":"liberal",
    "licentiously":"licentious",
    "licitly":"licit",
    "lifelessly":"lifeless",
    "light-handedly":"light-handed",
    "lightly":"light",
    "lightsomely":"lightsome",
    "limitedly":"limited",
    "limnologically":"limnological",
    "limpidly":"limpid",
    "lineally":"lineal",
    "linearly":"linear",
    "lingually":"lingual",
    "linguistically":"linguistic",
    "listlessly":"listless",
    "literally":"literal",
    "lividly":"livid",
    "locally":"local",
    "loftily":"lofty",
    "logarithmically":"logarithmic",
    "logically":"logical",
    "logogrammatically":"logogrammatic",
    "long-windedly":"long-winded",
    "longest":"long",
    "longitudinally":"longitudinal",
    "loosely":"loose",
    "lopsidedly":"lopsided",
    "loquaciously":"loquacious",
    "loudly":"loud",
    "lovingly":"loving",
    "loweringly":"lowering",
    "loyally":"loyal",
    "lucidly":"lucid",
    "luckily":"lucky",
    "ludicrously":"ludicrous",
    "lugubriously":"lugubrious",
    "lukewarmly":"lukewarm",
    "luridly":"lurid",
    "lusciously":"luscious",
    "lustfully":"lustful",
    "lustily":"lusty",
    "luxuriantly":"luxuriant",
    "luxuriously":"luxurious",
    "lyrically":"lyrical",
    "macroscopically":"macroscopical",
    "madly":"mad",
    "magically":"magical",
    "magisterially":"magisterial",
    "magna_cum_laude":"magna_cum_laude",
    "magnanimously":"magnanimous",
    "magnetically":"magnetic",
    "magnificently":"magnificent",
    "magniloquently":"magniloquent",
    "majestically":"majestic",
    "maladroitly":"maladroit",
    "malevolently":"malevolent",
    "maliciously":"malicious",
    "malignantly":"malignant",
    "malignly":"malign",
    "manageably":"manageable",
    "managerially":"managerial",
    "mandatorily":"mandatory",
    "manfully":"manful",
    "mangily":"mangy",
    "maniacally":"maniacal",
    "manifestly":"manifest",
    "manipulatively":"manipulative",
    "manually":"manual",
    "marginally":"marginal",
    "markedly":"marked",
    "martially":"martial",
    "marvellously":"marvelous",
    "masochistically":"masochistic",
    "massively":"massive",
    "masterfully":"masterful",
    "materialistically":"materialistic",
    "materially":"material",
    "maternally":"maternal",
    "mathematically":"mathematical",
    "matrilineally":"matrilineal",
    "maturely":"mature",
    "mawkishly":"mawkish",
    "maximally":"maximal",
    "meagerly":"meager",
    "meanderingly":"meandering",
    "meaningfully":"meaningful",
    "meanly":"mean",
    "meanspiritedly":"meanspirited",
    "measurably":"measurable",
    "measuredly":"measured",
    "mechanically":"mechanical",
    "medially":"medial",
    "medically":"medical",
    "medicinally":"medicinal",
    "meditatively":"meditative",
    "meekly":"meek",
    "mellowly":"mellow",
    "melodically":"melodic",
    "melodiously":"melodious",
    "melodramatically":"melodramatic",
    "memorably":"memorable",
    "menacingly":"menacing",
    "mendaciously":"mendacious",
    "menially":"menial",
    "mentally":"mental",
    "mercifully":"merciful",
    "mercilessly":"merciless",
    "merely":"mere",
    "meretriciously":"meretricious",
    "meritoriously":"meritorious",
    "merrily":"merry",
    "messily":"messy",
    "metabolically":"metabolic",
    "metaphorically":"metaphorical",
    "metaphysically":"metaphysical",
    "meteorologically":"meteorologic",
    "methodically":"methodical",
    "methodologically":"methodological",
    "meticulously":"meticulous",
    "metonymically":"metonymic",
    "metrically":"metrical",
    "microscopically":"microscopical",
    "microscopically":"microscopic",
    "mildly":"mild",
    "militarily":"military",
    "mincingly":"mincing",
    "mindfully":"mindful",
    "mindlessly":"mindless",
    "minimally":"minimal",
    "ministerially":"ministerial",
    "minutely":"minute",
    "miraculously":"miraculous",
    "mirthfully":"mirthful",
    "miserably":"miserable",
    "misleadingly":"misleading",
    "mistakenly":"mistaken",
    "mistily":"misty",
    "mistrustfully":"mistrustful",
    "mockingly":"mocking",
    "moderately":"moderate",
    "modestly":"modest",
    "modishly":"modish",
    "moistly":"moist",
    "momentously":"momentous",
    "monaurally":"monaural",
    "monolingually":"monolingual",
    "monosyllabically":"monosyllabic",
    "monotonously":"monotonous",
    "monstrously":"monstrous",
    "monthly":"monthly",
    "moodily":"moody",
    "moonily":"moony",
    "morbidly":"morbid",
    "mordaciously":"mordacious",
    "morosely":"morose",
    "morphologically":"morphological",
    "mostly":"most",
    "motionlessly":"motionless",
    "mournfully":"mournful",
    "movingly":"moving",
    "mulishly":"mulish",
    "multifariously":"multifarious",
    "multilaterally":"multilateral",
    "multiplicatively":"multiplicative",
    "multiply":"multiple",
    "mundanely":"mundane",
    "municipally":"municipal",
    "munificently":"munificent",
    "murderously":"murderous",
    "murkily":"murky",
    "musically":"musical",
    "musicologically":"musicological",
    "musingly":"musing",
    "mutely":"mute",
    "mutually":"mutual",
    "mysteriously":"mysterious",
    "mystically":"mystical",
    "naively":"naive",
    "nakedly":"naked",
    "narrow-mindedly":"narrow-minded",
    "narrowly":"narrow",
    "nasally":"nasal",
    "nastily":"nasty",
    "nationally":"national",
    "nattily":"natty",
    "naturally":"natural",
    "naughtily":"naughty",
    "neatly":"neat",
    "nebulously":"nebulous",
    "necessarily":"necessary",
    "neck_and_neck":"neck_and_neck",
    "needfully":"needful",
    "needlessly":"needless",
    "nefariously":"nefarious",
    "negatively":"negative",
    "neglectfully":"neglectful",
    "negligently":"negligent",
    "nervelessly":"nerveless",
    "nervily":"nervy",
    "nervously":"nervous",
    "neurobiological":"neurobiological",
    "neurotically":"neurotic",
    "nicely":"nice",
    "nimbly":"nimble",
    "nip_and_tuck":"nip_and_tuck",
    "nobly":"noble",
    "nocturnally":"nocturnal",
    "noiselessly":"noiseless",
    "noisily":"noisy",
    "nominally":"nominal",
    "nonchalantly":"nonchalant",
    "noncompetitively":"noncompetitive",
    "noncomprehensively":"noncomprehensive",
    "nonlexically":"nonlexical",
    "nonspecifically":"nonspecific",
    "nonverbally":"nonverbal",
    "nonviolently":"nonviolent",
    "northeastwardly":"northeastward",
    "northerly":"northerly",
    "northwestwardly":"northwestward",
    "noticeably":"noticeable",
    "noxiously":"noxious",
    "numbly":"numb",
    "numerically":"numerical",
    "nutritionally":"nutritional",
    "nuttily":"nutty",
    "obdurately":"obdurate",
    "obediently":"obedient",
    "objectionably":"objectionable",
    "objectively":"objective",
    "obligatorily":"obligatory",
    "obligingly":"obliging",
    "obliquely":"oblique",
    "obnoxiously":"obnoxious",
    "obscenely":"obscene",
    "obscurely":"obscure",
    "obsequiously":"obsequious",
    "observably":"observable",
    "observantly":"observant",
    "observingly":"observing",
    "obsessionally":"obsessional",
    "obsessively":"obsessive",
    "obstinately":"obstinate",
    "obstreperously":"obstreperous",
    "obstructively":"obstructive",
    "obtrusively":"obtrusive",
    "obtusely":"obtuse",
    "obviously":"obvious",
    "occasionally":"occasional",
    "oddly":"odd",
    "odiously":"odious",
    "offensively":"offensive",
    "offhandedly":"offhanded",
    "officially":"official",
    "officiously":"officious",
    "ominously":"ominous",
    "onerously":"onerous",
    "opaquely":"opaque",
    "openly":"open",
    "operationally":"operational",
    "operatively":"operative",
    "opportunely":"opportune",
    "oppositely":"opposite",
    "oppressively":"oppressive",
    "optically":"optical",
    "optimally":"optimal",
    "optimistically":"optimistic",
    "optionally":"optional",
    "opulently":"opulent",
    "orad":"oral",
    "ordinarily":"ordinary",
    "organically":"organic",
    "organizationally":"organizational",
    "originally":"original",
    "ornamentally":"ornamental",
    "osmotically":"osmotic",
    "ostensibly":"ostensible",
    "ostentatiously":"ostentatious",
    "outlandishly":"outlandish",
    "outrageously":"outrageous",
    "outspokenly":"outspoken",
    "outstandingly":"outstanding",
    "outwardly":"outward",
    "overbearingly":"overbearing",
    "overpoweringly":"overpowering",
    "overtly":"overt",
    "overwhelmingly":"overwhelming",
    "owlishly":"owlish",
    "pacifically":"pacific",
    "pacifistically":"pacifistic",
    "painfully":"painful",
    "painlessly":"painless",
    "painstakingly":"painstaking",
    "palatably":"palatable",
    "palely":"pale",
    "pallidly":"pallid",
    "palmately":"palmate",
    "palpably":"palpable",
    "paradoxically":"paradoxical",
    "parasitically":"parasitic",
    "pardonably":"pardonable",
    "parentally":"parental",
    "parenterally":"parenteral",
    "parenthetically":"parenthetical",
    "parochially":"parochial",
    "partially":"partial",
    "particularly":"particular",
    "passionately":"passionate",
    "passively":"passive",
    "patchily":"patchy",
    "patently":"patent",
    "paternally":"paternal",
    "pathetically":"pathetic",
    "pathogenically":"pathogenic",
    "pathologically":"pathological",
    "patiently":"patient",
    "patrilineally":"patrilineal",
    "patriotically":"patriotic",
    "patronisingly":"patronising",
    "patronizingly":"patronizing",
    "peaceably":"peaceable",
    "peacefully":"peaceful",
    "peculiarly":"peculiar",
    "pedagogically":"pedagogic",
    "pedantically":"pedantic",
    "peevishly":"peevish",
    "pejoratively":"pejorative",
    "pellucidly":"pellucid",
    "penally":"penal",
    "penetratingly":"penetrating",
    "penetratively":"penetrative",
    "penitentially":"penitential",
    "penitently":"penitent",
    "pensively":"pensive",
    "penuriously":"penurious",
    "perceptibly":"perceptible",
    "perceptively":"perceptive",
    "perceptually":"perceptual",
    "peremptorily":"peremptory",
    "perennially":"perennial",
    "perfectly":"perfect",
    "perfidiously":"perfidious",
    "perfunctorily":"perfunctory",
    "perilously":"perilous",
    "periodically":"periodical",
    "peripherally":"peripheral",
    "perkily":"perky",
    "permanently":"permanent",
    "permissibly":"permissible",
    "permissively":"permissive",
    "perniciously":"pernicious",
    "perpendicularly":"perpendicular",
    "perpetually":"perpetual",
    "perplexedly":"perplexed",
    "perseveringly":"persevering",
    "persistently":"persistent",
    "personally":"personal",
    "perspicuously":"perspicuous",
    "persuasively":"persuasive",
    "pertinaciously":"pertinacious",
    "pertinently":"pertinent",
    "pertly":"pert",
    "pervasively":"pervasive",
    "perversely":"perverse",
    "pessimistically":"pessimistic",
    "pettily":"petty",
    "pettishly":"pettish",
    "petulantly":"petulant",
    "pharmacologically":"pharmacological",
    "phenomenally":"phenomenal",
    "philanthropically":"philanthropic",
    "philatelically":"philatelic",
    "philosophically":"philosophical",
    "phlegmatically":"phlegmatic",
    "phonemic":"phonemic",
    "phonetically":"phonetic",
    "photoelectrically":"photoelectric",
    "photographically":"photographic",
    "photometrically":"photometric",
    "phylogenetically":"phylogenetic",
    "physically":"physical",
    "physiologically":"physiological",
    "pianissimo":"pianissimo",
    "piano":"piano",
    "pictorially":"pictorial",
    "picturesquely":"picturesque",
    "piercingly":"piercing",
    "pig-headedly":"pigheaded",
    "piggishly":"piggish",
    "pinnately":"pinnate",
    "piously":"pious",
    "piquantly":"piquant",
    "piratically":"piratical",
    "piteously":"piteous",
    "pithily":"pithy",
    "pitiably":"pitiable",
    "pitifully":"pitiful",
    "pitilessly":"pitiless",
    "placatingly":"placating",
    "placidly":"placid",
    "plaguily":"plaguy",
    "plainly":"plain",
    "plaintively":"plaintive",
    "plastically":"plastic",
    "plausibly":"plausible",
    "playfully":"playful",
    "pleasantly":"pleasant",
    "pleasingly":"pleasing",
    "pleasurably":"pleasurable",
    "plenarily":"plenary",
    "plenteously":"plenteous",
    "plentifully":"plentiful",
    "ploddingly":"plodding",
    "pluckily":"plucky",
    "pneumatically":"pneumatic",
    "poetically":"poetic",
    "poignantly":"poignant",
    "pointedly":"pointed",
    "pointlessly":"pointless",
    "poisonously":"poisonous",
    "polemically":"polemic",
    "politely":"polite",
    "politically":"political",
    "polygonally":"polygonal",
    "polyphonically":"polyphonic",
    "polysyllabically":"polysyllabic",
    "pompously":"pompous",
    "ponderously":"ponderous",
    "poorly":"poor",
    "popishly":"popish",
    "popularly":"popular",
    "pornographically":"pornographic",
    "portentously":"portentous",
    "positively":"positive",
    "possessively":"possessive",
    "possibly":"possible",
    "posthumously":"posthumous",
    "postoperatively":"postoperative",
    "potentially":"potential",
    "potently":"potent",
    "powerfully":"powerful",
    "powerlessly":"powerless",
    "practicably":"practicable",
    "practically":"practical",
    "pragmatically":"pragmatic",
    "praiseworthily":"praiseworthy",
    "precariously":"precarious",
    "precedentedly":"precedented",
    "precipitately":"precipitate",
    "precipitously":"precipitous",
    "precisely":"precise",
    "precociously":"precocious",
    "predicatively":"predicative",
    "predictably":"predictable",
    "predominantly":"predominant",
    "preeminently":"preeminent",
    "preferentially":"preferential",
    "prematurely":"premature",
    "preponderantly":"preponderant",
    "prepositionally":"prepositional",
    "presciently":"prescient",
    "presentably":"presentable",
    "presently":"present",
    "presidentially":"presidential",
    "pressingly":"pressing",
    "presumably":"presumable",
    "presumptuously":"presumptuous",
    "pretentiously":"pretentious",
    "preternaturally":"preternatural",
    "prettily":"pretty",
    "previously":"previous",
    "priggishly":"priggish",
    "primarily":"primary",
    "primitively":"primitive",
    "primly":"prim",
    "principally":"principal",
    "prissily":"prissy",
    "privately":"private",
    "probabilistically":"probabilistic",
    "probably":"probable",
    "problematically":"problematic",
    "prodigally":"prodigal",
    "prodigiously":"prodigious",
    "productively":"productive",
    "profanely":"profane",
    "professedly":"professed",
    "professionally":"professional",
    "professorially":"professorial",
    "proficiently":"proficient",
    "profitlessly":"profitless",
    "profligately":"profligate",
    "profoundly":"profound",
    "progressively":"progressive",
    "prohibitively":"prohibitive",
    "prominently":"prominent",
    "promiscuously":"promiscuous",
    "promisingly":"promising",
    "promptly":"prompt",
    "properly":"proper",
    "prophetically":"prophetic",
    "propitiously":"propitious",
    "proportionally":"proportional",
    "proportionately":"proportionate",
    "prosaically":"prosaic",
    "prosily":"prosy",
    "prosperously":"prosperous",
    "protectively":"protective",
    "protractedly":"protracted",
    "proudly":"proud",
    "provably":"provable",
    "proverbially":"proverbial",
    "providentially":"providential",
    "providently":"provident",
    "provincially":"provincial",
    "provisionally":"provisional",
    "provocatively":"provocative",
    "provokingly":"provoking",
    "prudently":"prudent",
    "prudishly":"prudish",
    "pruriently":"prurient",
    "pryingly":"prying",
    "psychically":"psychic",
    "psychologically":"psychological",
    "publicly":"public",
    "puckishly":"puckish",
    "pugnaciously":"pugnacious",
    "punctiliously":"punctilious",
    "punctually":"punctual",
    "pungently":"pungent",
    "punily":"puny",
    "punishingly":"punishing",
    "punitively":"punitive",
    "punitorily":"punitory",
    "puritanically":"puritanical",
    "purposefully":"purposeful",
    "purposelessly":"purposeless",
    "pusillanimously":"pusillanimous",
    "pyramidically":"pyramidical",
    "quaintly":"quaint",
    "qualitatively":"qualitative",
    "quantitatively":"quantitative",
    "quarterly":"quarterly",
    "quaveringly":"quavering",
    "queasily":"queasy",
    "queerly":"queer",
    "querulously":"querulous",
    "questionably":"questionable",
    "questioningly":"questioning",
    "quickly":"quick",
    "quietly":"quiet",
    "quixotically":"quixotic",
    "quizzically":"quizzical",
    "racially":"racial",
    "racily":"racy",
    "radially":"radial",
    "radiantly":"radiant",
    "radically":"radical",
    "radioactively":"radioactive",
    "raffishly":"raffish",
    "raggedly":"ragged",
    "rakishly":"rakish",
    "rampantly":"rampant",
    "randomly":"random",
    "rapaciously":"rapacious",
    "rapidly":"rapid",
    "rapturously":"rapturous",
    "rarely":"rare",
    "rashly":"rash",
    "raspingly":"rasping",
    "rationally":"rational",
    "raucously":"raucous",
    "ravenously":"ravenous",
    "ravishingly":"ravishing",
    "readably":"readable",
    "realistically":"realistic",
    "really":"real",
    "reasonably":"reasonable",
    "reassuringly":"reassuring",
    "rebelliously":"rebellious",
    "recently":"recent",
    "receptively":"receptive",
    "reciprocally":"reciprocal",
    "recklessly":"reckless",
    "recognizably":"recognizable",
    "recurrently":"recurrent",
    "redly":"red",
    "reflectively":"reflective",
    "reflexly":"reflex",
    "refreshingly":"refreshing",
    "regally":"regal",
    "regimentally":"regimental",
    "regionally":"regional",
    "regretfully":"regretful",
    "regrettably":"regrettable",
    "regularly":"regular",
    "relatively":"relative",
    "relativistically":"relativistic",
    "relentlessly":"relentless",
    "relevantly":"relevant",
    "reliably":"reliable",
    "religiously":"religious",
    "reluctantly":"reluctant",
    "remarkably":"remarkable",
    "reminiscently":"reminiscent",
    "remorsefully":"remorseful",
    "remorselessly":"remorseless",
    "remotely":"remote",
    "repeatedly":"repeated",
    "repellently":"repellent",
    "repellingly":"repelling",
    "repentantly":"repentant",
    "repetitively":"repetitive",
    "reportedly":"reported",
    "reprehensibly":"reprehensible",
    "reproachfully":"reproachful",
    "reproducibly":"reproducible",
    "reprovingly":"reproving",
    "repulsively":"repulsive",
    "reputably":"reputable",
    "resentfully":"resentful",
    "reservedly":"reserved",
    "residentially":"residential",
    "resolutely":"resolute",
    "resoundingly":"resounding",
    "resourcefully":"resourceful",
    "respectably":"respectable",
    "respectfully":"respectful",
    "respectively":"respective",
    "resplendently":"resplendent",
    "responsibly":"responsible",
    "restfully":"restful",
    "restively":"restive",
    "restlessly":"restless",
    "restrictively":"restrictive",
    "retentively":"retentive",
    "reticently":"reticent",
    "retroactively":"retroactive",
    "retrospectively":"retrospective",
    "revengefully":"revengeful",
    "reverentially":"reverential",
    "reverently":"reverent",
    "reversibly":"reversible",
    "revoltingly":"revolting",
    "rewardingly":"rewarding",
    "rhapsodically":"rhapsodic",
    "rhetorically":"rhetorical",
    "rhythmically":"rhythmical",
    "richly":"rich",
    "ridiculously":"ridiculous",
    "right":"right",
    "righteously":"righteous",
    "rightfully":"rightful",
    "rigidly":"rigid",
    "rigorously":"rigorous",
    "riotously":"riotous",
    "ripely":"ripe",
    "riskily":"risky",
    "robustly":"robust",
    "roguishly":"roguish",
    "rollickingly":"rollicking",
    "romantically":"romantic",
    "roomily":"roomy",
    "rotationally":"rotational",
    "rottenly":"rotten",
    "rotundly":"rotund",
    "roughly":"rough",
    "roundly":"round",
    "rowdily":"rowdy",
    "royally":"royal",
    "rudely":"rude",
    "ruefully":"rueful",
    "ruggedly":"rugged",
    "ruinously":"ruinous",
    "rurally":"rural",
    "ruthlessly":"ruthless",
    "sacredly":"sacred",
    "sacrilegiously":"sacrilegious",
    "sadly":"sad",
    "sagaciously":"sagacious",
    "sagely":"sage",
    "salaciously":"salacious",
    "sanctimoniously":"sanctimonious",
    "sanely":"sane",
    "sapiently":"sapient",
    "sarcastically":"sarcastic",
    "sardonically":"sardonic",
    "satirically":"satirical",
    "satisfactorily":"satisfactory",
    "saucily":"saucy",
    "savagely":"savage",
    "scandalously":"scandalous",
    "scantily":"scanty",
    "scarcely":"scarce",
    "scarily":"scary",
    "scathingly":"scathing",
    "scenically":"scenic",
    "sceptically":"sceptical",
    "schematically":"schematic",
    "schismatically":"schismatic",
    "scholastically":"scholastic",
    "scientifically":"scientific",
    "scorching":"scorching",
    "scornfully":"scornful",
    "scrappily":"scrappy",
    "screakily":"screaky",
    "screamingly":"screaming",
    "scrumptiously":"scrumptious",
    "scrupulously":"scrupulous",
    "scurrilously":"scurrilous",
    "scurvily":"scurvy",
    "searchingly":"searching",
    "seasonably":"seasonable",
    "seasonally":"seasonal",
    "second_hand":"secondhand",
    "secondarily":"secondary",
    "secretively":"secretive",
    "secretly":"secret",
    "securely":"secure",
    "seductively":"seductive",
    "sedulously":"sedulous",
    "seemingly":"seeming",
    "selectively":"selective",
    "self-conceitedly":"self-conceited",
    "self-consciously":"self-conscious",
    "self-evidently":"self-evident",
    "self-indulgently":"self-indulgent",
    "self-righteously":"self-righteous",
    "selfishly":"selfish",
    "selflessly":"selfless",
    "semantically":"semantic",
    "semiannually":"semiannual",
    "semimonthly":"semimonthly",
    "semiweekly":"semiweekly",
    "sensationally":"sensational",
    "senselessly":"senseless",
    "sensibly":"sensible",
    "sensitively":"sensitive",
    "sensually":"sensual",
    "sensuously":"sensuous",
    "sententiously":"sententious",
    "sentimentally":"sentimental",
    "separably":"separable",
    "separately":"separate",
    "sequentially":"sequential",
    "serenely":"serene",
    "serially":"serial",
    "seriously":"serious",
    "servilely":"servile",
    "seventhly":"seventh",
    "severely":"severe",
    "sexually":"sexual",
    "shabbily":"shabby",
    "shaggily":"shaggy",
    "shakily":"shaky",
    "shallowly":"shallow",
    "shambolically":"shambolic",
    "shamefacedly":"shamefaced",
    "shamefully":"shameful",
    "shamelessly":"shameless",
    "shapelessly":"shapeless",
    "sharply":"sharp",
    "sheepishly":"sheepish",
    "shiftily":"shifty",
    "shockingly":"shocking",
    "shoddily":"shoddy",
    "shortly":"short",
    "showily":"showy",
    "shrewdly":"shrewd",
    "shrewishly":"shrewish",
    "shrilly":"shrill",
    "shyly":"shy",
    "sickeningly":"sickening",
    "sidearm":"sidearm",
    "sidesplittingly":"sidesplitting",
    "signally":"signal",
    "significantly":"significant",
    "silently":"silent",
    "similarly":"similar",
    "simply":"simple",
    "simultaneously":"simultaneous",
    "sincerely":"sincere",
    "single-mindedly":"single-minded",
    "singly":"single",
    "singularly":"singular",
    "sinuously":"sinuous",
    "sinusoidally":"sinusoidal",
    "sixthly":"sixth",
    "sketchily":"sketchy",
    "skillfully":"skillful",
    "skimpily":"skimpy",
    "skittishly":"skittish",
    "slackly":"slack",
    "slanderously":"slanderous",
    "slangily":"slangy",
    "slantingly":"slanting",
    "slavishly":"slavish",
    "sleekly":"sleek",
    "sleepily":"sleepy",
    "sleeplessly":"sleepless",
    "slenderly":"slender",
    "slightingly":"slighting",
    "slightly":"slight",
    "slimly":"slim",
    "slopingly":"sloping",
    "sloppily":"sloppy",
    "slouchily":"slouchy",
    "slowly":"slow",
    "sluggishly":"sluggish",
    "slyly":"sly",
    "small-mindedly":"small-minded",
    "smarmily":"smarmy",
    "smartly":"smart",
    "smolderingly":"smoldering",
    "smoothly":"smooth",
    "smoulderingly":"smouldering",
    "smugly":"smug",
    "smuttily":"smutty",
    "snappishly":"snappish",
    "sneakily":"sneaky",
    "sneakingly":"sneaking",
    "sneeringly":"sneering",
    "snidely":"snide",
    "snobbishly":"snobbish",
    "snootily":"snooty",
    "snugly":"snug",
    "soberly":"sober",
    "sociably":"sociable",
    "socially":"social",
    "sociobiologically":"sociobiological",
    "socioeconomically":"socioeconomic",
    "sociolinguistically":"sociolinguistic",
    "sociologically":"sociological",
    "softly":"soft",
    "solely":"sole",
    "solemnly":"solemn",
    "solicitously":"solicitous",
    "solidly":"solid",
    "solitarily":"solitary",
    "somberly":"somber",
    "somnolently":"somnolent",
    "sonorously":"sonorous",
    "soothingly":"soothing",
    "sordidly":"sordid",
    "sorely":"sore",
    "sorrowfully":"sorrowful",
    "sottishly":"sottish",
    "soughingly":"soughing",
    "soulfully":"soulful",
    "soullessly":"soulless",
    "soundlessly":"soundless",
    "soundly":"sound",
    "sourly":"sour",
    "southeastwardly":"southeastward",
    "southerly":"southerly",
    "southwestwardly":"southwestward",
    "spaciously":"spacious",
    "sparely":"spare",
    "sparingly":"sparing",
    "sparsely":"sparse",
    "spasmodically":"spasmodic",
    "spatially":"spacial",
    "specially":"special",
    "specifically":"specific",
    "speciously":"specious",
    "spectacularly":"spectacular",
    "spectrographically":"spectrographic",
    "speculatively":"speculative",
    "speechlessly":"speechless",
    "speedily":"speedy",
    "spherically":"spherical",
    "spicily":"spicy",
    "spinally":"spinal",
    "spirally":"spiral",
    "spiritedly":"spirited",
    "spiritually":"spiritual",
    "spitefully":"spiteful",
    "splendidly":"splendid",
    "spontaneously":"spontaneous",
    "sporadically":"sporadic",
    "sportingly":"sporting",
    "spotlessly":"spotless",
    "sprucely":"spruce",
    "spuriously":"spurious",
    "squalidly":"squalid",
    "squarely":"square",
    "squeamishly":"squeamish",
    "stably":"stable",
    "stagily":"stagy",
    "staidly":"staid",
    "standoffishly":"standoffish",
    "starkly":"stark",
    "startlingly":"startling",
    "statistically":"statistical",
    "statutorily":"statutory",
    "staunchly":"staunch",
    "steadfastly":"steadfast",
    "steadily":"steady",
    "stealthily":"stealthy",
    "steeply":"steep",
    "stereotypically":"stereotypical",
    "sternly":"stern",
    "stertorously":"stertorous",
    "stickily":"sticky",
    "stiffly":"stiff",
    "still":"still",
    "stiltedly":"stilted",
    "stingily":"stingy",
    "stirringly":"stirring",
    "stochastically":"stochastic",
    "stockily":"stocky",
    "stodgily":"stodgy",
    "stoically":"stoic",
    "stolidly":"stolid",
    "stonily":"stony",
    "stormily":"stormy",
    "stoutly":"stout",
    "straight":"straight",
    "straightforwardly":"straightforward",
    "strangely":"strange",
    "strategically":"strategic",
    "strenuously":"strenuous",
    "strictly":"strict",
    "stridently":"strident",
    "strikingly":"striking",
    "stringently":"stringent",
    "strongly":"strong",
    "structurally":"structural",
    "stubbornly":"stubborn",
    "studiously":"studious",
    "stuffily":"stuffy",
    "stunningly":"stunning",
    "stupendously":"stupendous",
    "stupidly":"stupid",
    "sturdily":"sturdy",
    "stylishly":"stylish",
    "stylistically":"stylistic",
    "suavely":"suave",
    "subconsciously":"subconscious",
    "subcutaneously":"subcutaneous",
    "subjectively":"subjective",
    "submissively":"submissive",
    "subsequently":"subsequent",
    "subserviently":"subservient",
    "substantially":"substantial",
    "subtly":"subtle",
    "successfully":"successful",
    "successively":"successive",
    "succinctly":"succinct",
    "suddenly":"sudden",
    "sufficiently":"sufficient",
    "suggestively":"suggestive",
    "suitably":"suitable",
    "sulkily":"sulky",
    "sullenly":"sullen",
    "sultrily":"sultry",
    "summa_cum_laude":"summa_cum_laude",
    "summarily":"summary",
    "sumptuously":"sumptuous",
    "sunnily":"sunny",
    "superbly":"superb",
    "superciliously":"supercilious",
    "superficially":"superficial",
    "superfluously":"superfluous",
    "superlatively":"superlative",
    "supernaturally":"supernatural",
    "superstitiously":"superstitious",
    "supinely":"supine",
    "supremely":"supreme",
    "surely":"sure",
    "surgically":"surgical",
    "surlily":"surly",
    "surpassingly":"surpassing",
    "surprisedly":"surprised",
    "surprisingly":"surprising",
    "surreptitiously":"surreptitious",
    "suspiciously":"suspicious",
    "sweepingly":"sweeping",
    "sweetly":"sweet",
    "swiftly":"swift",
    "syllabically":"syllabic",
    "symbiotically":"symbiotic",
    "symbolically":"symbolic",
    "symmetrically":"symmetrical",
    "sympathetically":"sympathetic",
    "symptomatically":"symptomatic",
    "synchronously":"synchronous",
    "synergistically":"synergistic",
    "synonymously":"synonymous",
    "syntactically":"syntactic",
    "synthetically":"synthetic",
    "systematically":"systematic",
    "tacitly":"tacit",
    "taciturnly":"taciturn",
    "tactfully":"tactful",
    "tactically":"tactical",
    "tactlessly":"tactless",
    "tactually":"tactual",
    "talkatively":"talkative",
    "talkily":"talky",
    "tamely":"tame",
    "tangentially":"tangential",
    "tangibly":"tangible",
    "tantalizingly":"tantalizing",
    "tardily":"tardy",
    "tartly":"tart",
    "tastefully":"tasteful",
    "tastelessly":"tasteless",
    "tastily":"tasty",
    "tattily":"tatty",
    "tautly":"taut",
    "tawdrily":"tawdry",
    "taxonomically":"taxonomic",
    "tearfully":"tearful",
    "teasingly":"teasing",
    "technically":"technical",
    "technologically":"technological",
    "tediously":"tedious",
    "telegraphically":"telegraphic",
    "telescopically":"telescopic",
    "tellingly":"telling",
    "temperamentally":"temperamental",
    "temperately":"temperate",
    "temporally":"temporal",
    "temporarily":"temporary",
    "temptingly":"tempting",
    "tenaciously":"tenacious",
    "tendentiously":"tendentious",
    "tenderly":"tender",
    "tensely":"tense",
    "tentatively":"tentative",
    "tenthly":"tenth",
    "tenuously":"tenuous",
    "terminally":"terminal",
    "terrestrially":"terrestrial",
    "terribly":"terrible",
    "terrifically":"terrific",
    "territorially":"territorial",
    "tersely":"terse",
    "testily":"testy",
    "tetchily":"tetchy",
    "thankfully":"thankful",
    "theatrically":"theatrical",
    "thematically":"thematic",
    "theologically":"theological",
    "theoretically":"theoretical",
    "therapeutically":"therapeutic",
    "thermally":"thermal",
    "thermodynamically":"thermodynamic",
    "thermostatically":"thermostatic",
    "thickly":"thick",
    "thievishly":"thievish",
    "thinly":"thin",
    "thirdhand":"thirdhand",
    "thirstily":"thirsty",
    "thoroughly":"thorough",
    "thoughtfully":"thoughtful",
    "thoughtlessly":"thoughtless",
    "threateningly":"threatening",
    "thriftily":"thrifty",
    "thriftlessly":"thriftless",
    "tidily":"tidy",
    "tightly":"tight",
    "timidly":"timid",
    "timorously":"timorous",
    "tiredly":"tired",
    "tirelessly":"tireless",
    "tiresomely":"tiresome",
    "tolerantly":"tolerant",
    "tonelessly":"toneless",
    "topically":"topical",
    "topographically":"topographical",
    "topologically":"topological",
    "toppingly":"topping",
    "torpidly":"torpid",
    "torturously":"torturous",
    "totally":"total",
    "touchily":"touchy",
    "touchingly":"touching",
    "toughly":"tough",
    "traditionally":"traditional",
    "tragically":"tragic",
    "traitorously":"traitorous",
    "tranquilly":"tranquil",
    "transcendentally":"transcendental",
    "transiently":"transient",
    "transitionally":"transitional",
    "transitively":"transitive",
    "transitorily":"transitory",
    "transparently":"transparent",
    "transversally":"transversal",
    "transversely":"transverse",
    "treacherously":"treacherous",
    "treasonably":"treasonable",
    "tremendously":"tremendous",
    "tremulously":"tremulous",
    "trenchantly":"trenchant",
    "trepidly":"trepid",
    "trickily":"tricky",
    "trimly":"trim",
    "trippingly":"tripping",
    "tritely":"trite",
    "triumphantly":"triumphant",
    "trivially":"trivial",
    "tropically":"tropical",
    "truculently":"truculent",
    "truly":"true",
    "trustfully":"trustful",
    "trustingly":"trusting",
    "truthfully":"truthful",
    "tumultuously":"tumultuous",
    "tunefully":"tuneful",
    "tunelessly":"tuneless",
    "turbulently":"turbulent",
    "turgidly":"turgid",
    "tutorially":"tutorial",
    "typically":"typical",
    "typographically":"typographic",
    "ulteriorly":"ulterior",
    "ultimately":"ultimate",
    "ultrasonically":"ultrasonic",
    "unabashedly":"unabashed",
    "unacceptably":"acceptable",
    "unaccompanied":"unaccompanied",
    "unaccountably":"unaccountable",
    "unachievably":"unachievable",
    "unadvisedly":"unadvised",
    "unalterably":"unalterable",
    "unambiguously":"unambiguous",
    "unambitiously":"unambitious",
    "unanimously":"unanimous",
    "unappealingly":"unappealing",
    "unappreciatively":"unappreciative",
    "unarguably":"unarguable",
    "unashamedly":"unashamed",
    "unassailably":"unassailable",
    "unassertively":"unassertive",
    "unassumingly":"unassuming",
    "unattainably":"unattainable",
    "unattractively":"unattractive",
    "unavoidably":"unavoidable",
    "unbecomingly":"unbecoming",
    "unbelievably":"unbelievable",
    "unbelievingly":"unbelieving",
    "unblinkingly":"unblinking",
    "unblushingly":"unblushing",
    "uncannily":"uncanny",
    "unceasingly":"unceasing",
    "unceremoniously":"unceremonious",
    "uncertainly":"uncertain",
    "unchangeably":"unchangeable",
    "uncharacteristically":"uncharacteristic",
    "unchivalrously":"unchivalrous",
    "uncivilly":"uncivil",
    "unclearly":"unclear",
    "uncomfortably":"uncomfortable",
    "uncommonly":"uncommon",
    "uncomplainingly":"uncomplaining",
    "uncompromisingly":"uncompromising",
    "unconcernedly":"unconcerned",
    "unconditionally":"unconditional",
    "unconsciously":"unconscious",
    "unconstitutionally":"unconstitutional",
    "uncontrollably":"uncontrolled",
    "uncontroversially":"uncontroversial",
    "unconventionally":"unconventional",
    "unconvincingly":"unconvincing",
    "uncouthly":"uncouth",
    "uncritically":"uncritical",
    "unctuously":"unctuous",
    "undecipherably":"undecipherable",
    "undemocratically":"undemocratic",
    "undeniably":"undeniable",
    "undependably":"undependable",
    "underhandedly":"underhand",
    "understandingly":"understanding",
    "undeservedly":"undeserved",
    "undesirably":"undesirable",
    "undiplomatically":"diplomatic",
    "undisputedly":"undisputed",
    "undramatically":"undramatic",
    "unduly":"undue",
    "uneasily":"uneasy",
    "unemotionally":"unemotional",
    "unendingly":"unending",
    "unenthusiastically":"unenthusiastic",
    "unequally":"unequal",
    "unequivocally":"unequivocal",
    "unerringly":"unerring",
    "unethically":"unethical",
    "unevenly":"uneven",
    "uneventfully":"uneventful",
    "unexcitingly":"unexciting",
    "unexpectedly":"unexpected",
    "unfailingly":"unfailing",
    "unfairly":"unfair",
    "unfaithfully":"unfaithful",
    "unfalteringly":"unfaltering",
    "unfashionably":"unfashionable",
    "unfavorably":"unfavorable",
    "unfeelingly":"unfeeling",
    "unfeignedly":"unfeigned",
    "unforgettably":"unforgettable",
    "unforgivably":"unforgivable",
    "unforgivingly":"unforgiving",
    "unfortunately":"unfortunate",
    "ungracefully":"ungraceful",
    "ungrammatically":"ungrammatical",
    "ungratefully":"ungrateful",
    "ungrudgingly":"ungrudging",
    "unhappily":"unhappy",
    "unhelpfully":"unhelpful",
    "unhesitatingly":"unhesitating",
    "unhurriedly":"unhurried",
    "unhygienically":"unhygienic",
    "uniformly":"uniform",
    "unilaterally":"unilateral",
    "unimaginably":"unimaginable",
    "unimaginatively":"unimaginative",
    "unimpeachably":"unimpeachable",
    "unimpressively":"unimpressive",
    "uninformatively":"uninformative",
    "uninstructively":"uninstructive",
    "unintelligently":"unintelligent",
    "unintelligibly":"unintelligible",
    "unintentionally":"unintentional",
    "uninterestingly":"uninteresting",
    "uninterruptedly":"uninterrupted",
    "uninvitedly":"uninvited",
    "uniquely":"unique",
    "unjustifiably":"unjustifiable",
    "unjustly":"unjust",
    "unkindly":"unkind",
    "unlawfully":"unlawful",
    "unluckily":"unlucky",
    "unmanageably":"unmanageable",
    "unmanfully":"unmanful",
    "unmelodiously":"unmelodious",
    "unmemorably":"unmemorable",
    "unmercifully":"unmerciful",
    "unmindfully":"unmindful",
    "unmistakably":"unmistakable",
    "unmusically":"unmusical",
    "unnaturally":"unnatural",
    "unnecessarily":"unnecessary",
    "unnoticeably":"unnoticeable",
    "unobtrusively":"unobtrusive",
    "unofficially":"unofficial",
    "unoriginally":"unoriginal",
    "unpalatably":"unpalatable",
    "unpardonably":"unpardonable",
    "unpatriotically":"unpatriotic",
    "unpleasantly":"unpleasant",
    "unprecedentedly":"unprecedented",
    "unpredictably":"unpredictable",
    "unpretentiously":"unpretentious",
    "unproductively":"unproductive",
    "unprofitably":"unprofitable",
    "unpropitiously":"unpropitious",
    "unqualifiedly":"unqualified",
    "unquestionably":"unquestionable",
    "unquestioningly":"unquestioning",
    "unquietly":"unquiet",
    "unreadably":"unreadable",
    "unrealistically":"unrealistic",
    "unreasonably":"unreasonable",
    "unrecognizably":"unrecognizable",
    "unrelentingly":"unrelenting",
    "unreliably":"unreliable",
    "unremarkably":"unremarkable",
    "unrepentantly":"unrepentant",
    "unreproducibly":"unreproducible",
    "unrestrainedly":"unrestrained",
    "unrighteously":"unrighteous",
    "unsatisfactorily":"unsatisfactory",
    "unscientifically":"unscientific",
    "unscrupulously":"unscrupulous",
    "unseasonably":"unseasonable",
    "unselfconsciously":"unselfconscious",
    "unselfishly":"unselfish",
    "unsentimentally":"unsentimental",
    "unshakably":"unshakable",
    "unsmilingly":"unsmiling",
    "unsociably":"unsociable",
    "unsparingly":"unsparing",
    "unspeakably":"unspeakable",
    "unsportingly":"unsporting",
    "unsteadily":"unsteady",
    "unstintingly":"unstinting",
    "unsuccessfully":"unsuccessful",
    "unsuspectingly":"unsuspecting",
    "unswervingly":"unswerving",
    "unsympathetically":"unsympathetic",
    "unsystematically":"unsystematic",
    "unthinkably":"unthinkable",
    "unthinkingly":"unthinking",
    "untidily":"untidy",
    "untimely":"untimely",
    "untruly":"untrue",
    "untruthfully":"untruthful",
    "untypically":"untypical",
    "unusually":"unusual",
    "unutterably":"unutterable",
    "unwantedly":"unwanted",
    "unwarily":"unwary",
    "unwarrantably":"unwarrantable",
    "unwaveringly":"unwavering",
    "unwillingly":"unwilling",
    "unwittingly":"unwitting",
    "unwontedly":"unwonted",
    "unworthily":"unworthy",
    "uppishly":"uppish",
    "uprightly":"upright",
    "uproariously":"uproarious",
    "urbanely":"urbane",
    "urgently":"urgent",
    "usefully":"useful",
    "uselessly":"useless",
    "usually":"usual",
    "usuriously":"usurious",
    "utterly":"utter",
    "uxoriously":"uxorious",
    "vacantly":"vacant",
    "vacuously":"vacuous",
    "vaguely":"vague",
    "vainly":"vain",
    "valiantly":"valiant",
    "validly":"valid",
    "valorously":"valorous",
    "vapidly":"vapid",
    "variably":"variable",
    "variously":"various",
    "vastly":"vast",
    "vehemently":"vehement",
    "venally":"venal",
    "vengefully":"vengeful",
    "venomously":"venomous",
    "ventrally":"ventral",
    "verbally":"verbal",
    "verbosely":"verbose",
    "vertically":"vertical",
    "vexatiously":"vexatious",
    "vicariously":"vicarious",
    "viciously":"vicious",
    "victoriously":"victorious",
    "vigilantly":"vigilant",
    "vigorously":"vigorous",
    "vilely":"vile",
    "vindictively":"vindictive",
    "violently":"violent",
    "virtually":"virtual",
    "virtuously":"virtuous",
    "virulently":"virulent",
    "viscerally":"visceral",
    "viscidly":"viscid",
    "visibly":"visible",
    "vitally":"vital",
    "vitriolically":"vitriolic",
    "vivaciously":"vivacious",
    "vividly":"vivid",
    "excite":"excited",
    "vocally":"vocal",
    "vocationally":"vocational",
    "vociferously":"vociferous",
    "volcanically":"volcanic",
    "volitionally":"volitional",
    "volubly":"voluble",
    "volumetrically":"volumetric",
    "voluntarily":"voluntary",
    "voluptuously":"voluptuous",
    "voraciously":"voracious",
    "voyeuristically":"voyeuristic",
    "vulgarly":"vulgar",
    "vulnerably":"vulnerable",
    "wackily":"wacky",
    "wafer-thin":"wafer-thin",
    "waggishly":"waggish",
    "wanly":"wan",
    "wantonly":"wanton",
    "warily":"wary",
    "warm":"warm",
    "wastefully":"wasteful",
    "watchfully":"watchful",
    "weakly":"weak",
    "wealthily":"wealthy",
    "wearily":"weary",
    "weightily":"weighty",
    "weirdly":"weird",
    "well":"good",
    "westerly":"west",
    "wheezily":"wheezy",
    "wheezingly":"wheezing",
    "wholeheartedly":"wholehearted",
    "wholesomely":"wholesome",
    "wholly":"whole",
    "wickedly":"wicked",
    "wild":"wild",
    "wilfully":"wilful",
    "willfully":"willful",
    "willingly":"willing",
    "windily":"windy",
    "winsomely":"winsome",
    "wisely":"wise",
    "wishfully":"wishful",
    "wistfully":"wistful",
    "witheringly":"withering",
    "wittily":"witty",
    "wittingly":"witting",
    "woefully":"woeful",
    "wolfishly":"wolfish",
    "wonderfully":"wonderful",
    "wonderingly":"wondering",
    "wondrously":"wondrous",
    "woodenly":"wooden",
    "wordily":"wordy",
    "wordlessly":"wordless",
    "worriedly":"worried",
    "worryingly":"worrying",
    "worthily":"worthy",
    "worthlessly":"worthless",
    "wrathfully":"wrathful",
    "wretchedly":"wretched",
    "wrongfully":"wrongful",
    "wrongheadedly":"wrongheaded",
    "wrongly":"wrong",
    "wryly":"wry",
    "yieldingly":"yielding",
    "youthfully":"youthful",
    "zealously":"zealous",
    "zestfully":"zestful",
    "zestily":"zesty"}

# %%
display(train_data[['tweet','tokenized_tweet','normalized_tweet','lemmatized_tweet']].iloc[:15])
# Out:
#                                                                                                                        tweet  \
# 0   just published a new blog post on ai technology awsm: check it out at http://www.exampleblog.com/ai-blog.  #ai #techblog
# 1    excited to share my latest recipe creation: try it out here at http://www.cookingdelights.com/recipes. #cooking #foodie
# 2                                                                             the bird flies high in the sky. #nature #peace
# 3                           what a thrilling cricket match today! nail-biting finish with a last-ball six! ???? #cricketfans
# 4           "late-night studies can be tough, but it`s kwl and all worth it in the end!  #latenightstudies #hardworkpaysoff"
# 5                                                     "loving the #fridayfeeling! can`t wait to have some fun this weekend.
# 6                                         had a great time with friends last night. feeling awsm today! #friends #goodtimes
# 7                                              that was a looooong day at work! time to relax and watch a movie.  #chilltime
# 8                                            i`m so tired of this weather. can`t wait for summer to come!  #readyforsunshine
# 9                                     working on my #newyearresolution to get fit and healthy.  #fitnessgoals #healthyliving
# 10                                          just finished reading an amazing book. highly recommend it!  #bookrecommendation
# 11                                          cooking dinner for the family tonight. hope it turns out delicious!  #familytime
# 12                  i`m having a fantastic day at the beach. the sun is shining, and the water is crystal clear! ? #beachday
# 13                                                 feeling a bit under the weather today. time to rest and recover. #sickday
# 15                                           i`m sorry, i can`t make it to the party tonight. have a great time without me!
#
#                                                                                                                   tokenized_tweet  \
# 0                            [just, published, a, new, blog, post, on, ai, technology, awesome, check, it, out, at, ai, techblog]
# 1                                     [excited, to, share, my, latest, recipe, creation, try, it, out, here, at, cooking, foodie]
# 2                                                                           [the, bird, flies, high, in, the, sky, nature, peace]
# 3                        [what, a, thrilling, cricket, match, today, nail, biting, finish, with, a, last, ball, six, cricketfans]
# 4   [late, night, studies, can, be, tough, but, it`s, cool, and, all, worth, it, in, the, end, latenightstudies, hardworkpaysoff]
# 5                                                   [loving, the, fridayfeeling, can`t, wait, to, have, some, fun, this, weekend]
# 6                                  [had, a, great, time, with, friends, last, night, feeling, awesome, today, friends, goodtimes]
# 7                                          [that, was, a, loong, day, at, work, time, to, relax, and, watch, a, movie, chilltime]
# 8                                       [i`m, so, tired, of, this, weather, can`t, wait, for, summer, to, come, readyforsunshine]
# 9                                   [working, on, my, newyearresolution, to, get, fit, and, healthy, fitnessgoals, healthyliving]
# 10                                        [just, finished, reading, an, amazing, book, highly, recommend, it, bookrecommendation]
# 11                                      [cooking, dinner, for, the, family, tonight, hope, it, turns, out, delicious, familytime]
# 12         [i`m, having, a, fantastic, day, at, the, beach, the, sun, is, shining, and, the, water, is, crystal, clear, beachday]
# 13                                           [feeling, a, bit, under, the, weather, today, time, to, rest, and, recover, sickday]
# 15                                   [i`m, sorry, i, can`t, make, it, to, the, party, tonight, have, a, great, time, without, me]
#
#                                                                           normalized_tweet  \
# 0               [published, new, blog, post, ai, technology, awesome, check, ai, techblog]
# 1                         [excited, share, latest, recipe, creation, try, cooking, foodie]
# 2                                                  [bird, flies, high, sky, nature, peace]
# 3   [thrilling, cricket, match, today, nail, biting, finish, last, ball, six, cricketfans]
# 4       [late, night, studies, tough, cool, worth, end, latenightstudies, hardworkpaysoff]
# 5                                      [loving, fridayfeeling, cannot, wait, fun, weekend]
# 6         [great, time, friends, last, night, feeling, awesome, today, friends, goodtimes]
# 7                                 [loong, day, work, time, relax, watch, movie, chilltime]
# 8                           [tired, weather, cannot, wait, summer, come, readyforsunshine]
# 9             [working, newyearresolution, get, fit, healthy, fitnessgoals, healthyliving]
# 10               [finished, reading, amazing, book, highly, recommend, bookrecommendation]
# 11                  [cooking, dinner, family, tonight, hope, turns, delicious, familytime]
# 12                  [fantastic, day, beach, sun, shining, water, crystal, clear, beachday]
# 13                            [feeling, bit, weather, today, time, rest, recover, sickday]
# 15                             [sorry, cannot, make, party, tonight, great, time, without]
#
#                                                                           lemmatized_tweet
# 0               [published, new, blog, post, ai, technology, awesome, check, ai, techblog]
# 1                         [excited, share, latest, recipe, creation, try, cooking, foodie]
# 2                                                  [bird, flies, high, sky, nature, peace]
# 3   [thrilling, cricket, match, today, nail, biting, finish, last, ball, six, cricketfans]
# 4       [late, night, studies, tough, cool, worth, end, latenightstudies, hardworkpaysoff]
# 5                                      [loving, fridayfeeling, cannot, wait, fun, weekend]
# 6         [great, time, friends, last, night, feeling, awesome, today, friends, goodtimes]
# 7                                 [loong, day, work, time, relax, watch, movie, chilltime]
# 8                           [tired, weather, cannot, wait, summer, come, readyforsunshine]
# 9             [working, newyearresolution, get, fit, healthy, fitnessgoals, healthyliving]
# 10                 [finished, reading, amazing, book, high, recommend, bookrecommendation]
# 11                  [cooking, dinner, family, tonight, hope, turns, delicious, familytime]
# 12                  [fantastic, day, beach, sun, shining, water, crystal, clear, beachday]
# 13                            [feeling, bit, weather, today, time, rest, recover, sickday]
# 15                             [sorry, cannot, make, party, tonight, great, time, without]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# Assuming you have X_train_tfidf and X_test_tfidf as TF-IDF matrices
# Assuming you have train_labels and test_labels as labels for your data

# Create and train a Multinomial Naive Bayes classifier
nb_classifier = MultinomialNB()
nb_classifier.fit(X_train_tfidf, train_labels)

# Make predictions on the test data
test_predictions = nb_classifier.predict(X_test_tfidf)

# Evaluate the classifier
accuracy = accuracy_score(test_labels, test_predictions)
classification_report_str = classification_report(test_labels, test_predictions)

# Print the evaluation metrics
print(f'Accuracy: {accuracy}')
print('Classification Report:')
print(classification_report_str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [100], in <cell line: 10>()
#       5 # Assuming you have X_train_tfidf and X_test_tfidf as TF-IDF matrices
#       6 # Assuming you have train_labels and test_labels as labels for your data
#       7
#       8 # Create and train a Multinomial Naive Bayes classifier
#       9 nb_classifier = MultinomialNB()
# ---> 10 nb_classifier.fit(X_train_tfidf, train_labels)
#      12 # Make predictions on the test data
#      13 test_predictions = nb_classifier.predict(X_test_tfidf)
#
# NameError: name 'X_train_tfidf' is not defined

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Join the lists of lemmatized words into sentences (strings)
train_data['lemm_sentences'] = train_data['lemm'].apply(lambda tokens: ' '.join(tokens))
test_data['lemm_sentences'] = test_data['lemm'].apply(lambda tokens: ' '.join(tokens))

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the vectorizer on the training data
X_train_tfidf = tfidf_vectorizer.fit_transform(train_data['lemm_sentences'])

# Transform the test data using the same vectorizer
X_test_tfidf = tfidf_vectorizer.transform(test_data['lemm_sentences'])

# %%
print("Number of samples in training data:", X_train_tfidf.shape[0])
print("Number of samples in training labels:", len(train_labels))

# %%
print("Training data shape:", X_train_tfidf.shape)
print("Testing data shape:", X_test_tfidf.shape)
print("Training labels shape:", train_labels.shape)
print("Testing labels shape:", test_labels.shape)

# %%
from sklearn.model_selection import train_test_split

# Split your data into training and testing sets
X_train_tfidf, X_test_tfidf, train_labels, test_labels = train_test_split(
    X_tfidf,  # Your TF-IDF data
    labels,   # Your corresponding labels
    test_size=0.2,  # Adjust the test size as needed
    random_state=42  # Set a random seed for reproducibility
)

# %%
train_labels

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Assuming you have X_train_tfidf and X_test_tfidf as TF-IDF matrices

# Create a Logistic Regression model
model = LogisticRegression()

# Train the model on the TF-IDF features and corresponding labels from the training data
model.fit(X_train_tfidf, train_labels)  # You need to replace train_labels with your actual labels

# Make predictions on the test data
test_predictions = model.predict(X_test_tfidf)

# Evaluate the model
accuracy = accuracy_score(test_labels, test_predictions)  # You need to replace test_labels with your actual labels
classification_report_str = classification_report(test_labels, test_predictions)

# Print the evaluation metrics
print(f'Accuracy: {accuracy}')
print('Classification Report:')
print(classification_report_str)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split

# Assuming you have the TF-IDF vectors from the previous step
# X_train_tfidf and X_test_tfidf

# Define your target labels (assuming you have them)
y = train_data['labels']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, y, test_size=0.2, random_state=42)

# Create a Logistic Regression model
model = LogisticRegression()

# Train the model on the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

# Print a classification report for more detailed evaluation
print(classification_report(y_test, y_pred))
